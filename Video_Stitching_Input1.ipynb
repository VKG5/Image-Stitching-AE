# %% [markdown]
# ### Importing Libraries

# %%
# !pip install opencv-contrib-python==3.4.2.17
# !pip install --upgrade imutils
# Out:
# Collecting opencv-contrib-python==3.4.2.17
#   Downloading https://files.pythonhosted.org/packages/61/29/fc60b2de1713aa92946992544329f20ccb5e4ba26290f403e04b7da44105/opencv_contrib_python-3.4.2.17-cp36-cp36m-manylinux1_x86_64.whl (30.6MB)
#      |████████████████████████████████| 30.6MB 138kB/s
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from opencv-contrib-python==3.4.2.17) (1.18.5)
# Installing collected packages: opencv-contrib-python
#   Found existing installation: opencv-contrib-python 4.1.2.30
#     Uninstalling opencv-contrib-python-4.1.2.30:
#       Successfully uninstalled opencv-contrib-python-4.1.2.30
# Successfully installed opencv-contrib-python-3.4.2.17
# Requirement already up-to-date: imutils in /usr/local/lib/python3.6/dist-packages (0.5.3)

# %%
import cv2
import numpy as np
import imutils
import matplotlib.pyplot as plt
from random import randrange
from google.colab.patches import cv2_imshow
import sys
import time
import os
import tqdm
from moviepy.editor import ImageSequenceClip

# For 24->8bit
from PIL import Image

# %matplotlib inline

# %% [markdown]
# For Stitcher

# %%
def cylindricalWarp(img, K):
    """This function returns the cylindrical warp for a given image and intrinsics matrix K"""
    h_,w_ = img.shape[:2]
    # pixel coordinates
    y_i, x_i = np.indices((h_,w_))
    X = np.stack([x_i,y_i,np.ones_like(x_i)],axis=-1).reshape(h_*w_,3) # to homog
    Kinv = np.linalg.inv(K) 
    X = Kinv.dot(X.T).T # normalized coords

    # calculate cylindrical coords (sin\theta, h, cos\theta)
    A = np.stack([np.sin(X[:,0]),X[:,1],np.cos(X[:,0])],axis=-1).reshape(w_*h_,3)
    B = K.dot(A.T).T # project back to image-pixels plane
    
    # back from homog coords
    B = B[:,:-1] / B[:,[-1]]
    
    # make sure warp coords only within image bounds
    B[(B[:,0] < 0) | (B[:,0] >= w_) | (B[:,1] < 0) | (B[:,1] >= h_)] = -1
    B = B.reshape(h_,w_,-1)
    
    # for transparent borders...
    img_rgba = cv2.cvtColor(img,cv2.COLOR_BGR2BGRA) 
    
    # warp the image according to cylindrical coords
    return cv2.remap(img_rgba, B[:,:,0].astype(np.float32), B[:,:,1].astype(np.float32), cv2.INTER_AREA, borderMode=cv2.BORDER_DEFAULT)

# %%
# To crop the black part of the stitched image

def trim(frame):
  # Cropping the top
  if not np.sum(frame[0]):
    return trim(frame[1:])

  if not np.sum(frame[-1]):
    return trim(frame[:-2])

  if not np.sum(frame[:, 0]):
    return trim(frame[:, 1:])

  if not np.sum(frame[:, -1]):
    return trim(frame[:, :-2])

  return frame

# %%
def trim_cyl(img):
  return img[:, 260:1650]

# %%
def cropping(final_color):
  stitched = final_color.copy()

  # create a 10 pixel border surrounding the stitched image
  # print("Cropping...")
  stitched = cv2.copyMakeBorder(stitched, 10, 10, 10, 10,
    cv2.BORDER_CONSTANT, (0, 0, 0))

  # convert the stitched image to grayscale and threshold it
  # such that all pixels greater than zero are set to 255
  # (foreground) while all others remain 0 (background)
  gray = cv2.cvtColor(stitched, cv2.COLOR_BGR2GRAY)
  thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY)[1]

  ## To get the intermediate results
  # plt.imshow(gray, cmap='gray')
  # plt.title("Gray Image")
  # plt.show()

  # plt.pause(0.2)

  # plt.imshow(thresh, cmap='gray')
  # plt.title("Threshold Image")
  # plt.show()

  # plt.pause(0.2)

  # find all external contours in the threshold image then find
  # the *largest* contour which will be the contour/outline of
  # the stitched image
  cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL,
    cv2.CHAIN_APPROX_SIMPLE)
  cnts = imutils.grab_contours(cnts)
  c = max(cnts, key=cv2.contourArea)

  # allocate memory for the mask which will contain the
  # rectangular bounding box of the stitched image region
  mask = np.zeros(thresh.shape, dtype="uint8")
  (x, y, w, h) = cv2.boundingRect(c)
  cv2.rectangle(mask, (x, y), (x + w, y + h), 255, -1)

  h = int(0.6*h)

  # plt.imshow(cv2.rectangle(mask, (x, y), (x + w, y + h), 255, -1), cmap='gray')
  # plt.title("Rectangular Mask")
  # plt.show()

  # plt.pause(0.2)

  # create two copies of the mask: one to serve as our actual
  # minimum rectangular region and another to serve as a counter
  # for how many pixels need to be removed to form the minimum
  # rectangular region
  minRect = mask.copy()

  # find contours in the minimum rectangular mask and then
  # extract the bounding box (x, y)-coordinates
  cnts = cv2.findContours(minRect.copy(), cv2.RETR_EXTERNAL,
    cv2.CHAIN_APPROX_SIMPLE)
  cnts = imutils.grab_contours(cnts)
  c = max(cnts, key=cv2.contourArea)
  (x, y, w, h) = cv2.boundingRect(c)

  # print(x, y, w, h)
  # use the bounding box coordinates to extract the our final
  # stitched image
  stitched_cropped = stitched[25: 25 + 1025, x:x + w]

  # Display the output stitched image to our screen
  # cv2_imshow(stitched_cropped)

  return stitched_cropped

# %%
def stitch(img_1, img_2):
  # img2 = cv2.imread('/content/Screenshot 2020-11-03 112809.png')
  # img3 = cv2.imread('/content/Screenshot 2020-11-03 112821.png')
  
  # img = cv2.cvtColor(img_1,cv2.COLOR_BGR2GRAY)
  # img = cv2.resize(img, (1024, 683))
  # imgm = cv2.cvtColor(img_2,cv2.COLOR_BGR2GRAY)
  # imgm = cv2.resize(imgm, (1024, 683))
  img = img_1.copy()
  imgm = img_2.copy()

  sift = cv2.xfeatures2d.SIFT_create()
  
  # Find the keypoints and descriptors with SIFT
  kp1, des1 = sift.detectAndCompute(imgm,None)
  kp2, des2 = sift.detectAndCompute(img,None)

  bf = cv2.BFMatcher()
  matches = bf.knnMatch(des1,des2, k=2)

  # Apply ratio test
  good = []
  alpha = 0.45
  for m in matches:
      if m[0].distance < alpha*m[1].distance:
          good.append(m)
  matches = np.asarray(good)

  if len(matches[:,0]) >= 7:
      src = np.float32([ kp1[m.queryIdx].pt for m in matches[:,0] ]).reshape(-1,1,2)
      dst = np.float32([ kp2[m.trainIdx].pt for m in matches[:,0] ]).reshape(-1,1,2)
      H, masked = cv2.findHomography(src, dst, cv2.RANSAC, 5.0)
      
      '''
      Optional
      '''
      # Getting the dimensions of the image (To be used soon)
      # h, w = img.shape

      # pts = np.float32([ [0,0], [0, h-1], [w-1, h-1], [w-1,0 ] ]).reshape(-1,1,2)
      # img__ = cv2.perspectiveTransform(pts, H)

      '''
      To plot a line to display the stitch boundary
      '''
      # img_ = cv2.polylines(imgm, [np.int32(img__)], True, 255, 3, cv2.LINE_AA)
      
      '''
      To print the overlapping image
      '''
      # To reduce the file size
      # plt.imshow(imgm, cmap='gray')
      # cv2_imshow(img_)

  else:
      print("Cannot find enough keypoints.")
      pass

  # Homography Matrix
  # print(H)

  stitched = cv2.warpPerspective(imgm, H, (img.shape[1] + imgm.shape[1], img.shape[0]))
  stitched[0:img.shape[0], 0:img.shape[1]] = img

  stitched = cv2.cvtColor(stitched, cv2.COLOR_BGRA2RGB)

  return stitched

# %%
def stitch_images(img1, img2, img3):
  # Getting the images
  img1 = img1.astype('uint8')
  img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)

  img2 = img2.astype('uint8')
  img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

  img3 = img3.astype('uint8')
  img3 = cv2.cvtColor(img3, cv2.COLOR_BGR2RGB)

  ### Preprocessing
  ## Cylindrical Wrapping
  h, w = img1.shape[:2]
  K = np.array([[800,0,w/2],[0,800,h/2],[0,0,1]]) # mock intrinsics

  # Applying the cylindrical warping
  img_cyl1 = cylindricalWarp(img1, K)
  img_cyl2 = cylindricalWarp(img2, K)
  img_cyl3 = cylindricalWarp(img3, K)

  # Cylindrical Trimming the images
  img_cyl1_crop = trim_cyl(img_cyl1)
  img_cyl2_crop = trim_cyl(img_cyl2)
  img_cyl3_crop = trim_cyl(img_cyl3)

  '''
  **Trying the following:**
  1. Left-Middle
  2. Middle-Right
  3. (1)+(2) - Whole 3 stitched together
  '''

  #### Computing the left-mid
  ### Reversing the middle and left image
  ## Middle
  img_cyl2_crop = cv2.flip(img_cyl2_crop, 1)

  # Left
  img_cyl1_crop = cv2.flip(img_cyl1_crop, 1)

  # Joining Left-Mid
  lm = stitch(img_cyl2_crop, img_cyl1_crop)
  lm = trim(lm)

  # Flipping the result
  lm = cv2.flip(lm, 1)

  #### Computing the mid-right 
  ### Flipping to get middle to original values
  img_cyl2_crop = cv2.flip(img_cyl2_crop, 1)

  # Joining Mid-Right
  mr = stitch(img_cyl2_crop, img_cyl3_crop)
  mr = trim(mr)

  #### Left-Mid + Mid-Right
  final = stitch(lm, mr)
  final = trim(final)

  # Converting to RGB again
  final_color = cv2.cvtColor(final, cv2.COLOR_BGRA2RGB)

  # Cropping the stretched image
  stitched_final = cropping(final_color)

  # Resizing the image
  stitched_cropped_resized = cv2.resize(stitched_final, (1920, 720))

  return stitched_cropped_resized

# %%
def run(left_video, mid_video, right_video):
  
  # Get information about the videos
  n_frames = min( int(left_video.get(cv2.CAP_PROP_FRAME_COUNT)),
                  int(mid_video.get(cv2.CAP_PROP_FRAME_COUNT)),
                  int(right_video.get(cv2.CAP_PROP_FRAME_COUNT)) )
  
  fps = int(left_video.get(cv2.CAP_PROP_FPS))
  frames = []

  count = -1
  for _ in tqdm.tqdm(np.arange(n_frames)):
    
    count += 1

    if (count>-1 and count<1000):
      # Grab the frames from their respective video streams
      ok, left = left_video.read()
      _, mid = mid_video.read()
      _, right = right_video.read()

      if ok:
        # Stitch the frames together to form the panorama
        stitched_frame = stitch_images(left, mid, right)
          
        # No homography could not be computed
        if stitched_frame is None:
          print("[INFO]: Homography could not be computed!")
          continue

        # Add frame to video
        frames.append(stitched_frame)

    elif (count==1000):
      print("Finished Processing!")
      break

    else:
      print("Skipping!")
      
  cv2.destroyAllWindows()
  return frames

# %%
# Defining the paths

left_video_in_path='/content/drive/My Drive/Colab Notebooks/Carla Dataset/City/Left.mp4'
mid_video_in_path='/content/drive/My Drive/Colab Notebooks/Carla Dataset/City/Front.mp4'
right_video_in_path='/content/drive/My Drive/Colab Notebooks/Carla Dataset/City/Right.mp4'

# %%
# Set up video capture
left_video = cv2.VideoCapture(left_video_in_path)
mid_video = cv2.VideoCapture(mid_video_in_path)
right_video = cv2.VideoCapture(right_video_in_path)
print('[INFO]: {}, {} and {} loaded'.format(  left_video_in_path.split('/')[-1],
                                              mid_video_in_path.split('/')[-1],
                                              right_video_in_path.split('/')[-1])  )

print('[INFO]: Image Processing starting....')

# The frames of the stitched images
frames = run(left_video, mid_video, right_video)
# Out:
#   0%|          | 0/14850 [00:00<?, ?it/s]
# [INFO]: Left.mp4, Front.mp4 and Right.mp4 loaded
# [INFO]: Image Processing starting....
#   0%|          | 1/14850 [00:06<25:46:22,  6.25s/it]
#   0%|          | 2/14850 [00:12<25:35:16,  6.20s/it]
#   0%|          | 3/14850 [00:22<30:03:56,  7.29s/it]
#   0%|          | 4/14850 [00:32<33:42:24,  8.17s/it]
#   0%|          | 5/14850 [00:42<35:48:03,  8.68s/it]
#   0%|          | 6/14850 [00:52<37:05:20,  8.99s/it]
#   0%|          | 7/14850 [01:01<37:31:23,  9.10s/it]
#   0%|          | 8/14850 [01:10<37:50:02,  9.18s/it]
#   0%|          | 9/14850 [01:19<37:55:09,  9.20s/it]
#   0%|          | 10/14850 [01:29<38:19:10,  9.30s/it]
#   0%|          | 11/14850 [01:38<38:34:00,  9.36s/it]
#   0%|          | 12/14850 [01:48<38:26:36,  9.33s/it]
#   0%|          | 13/14850 [01:57<38:22:47,  9.31s/it]
#   0%|          | 14/14850 [02:10<42:48:06, 10.39s/it]
#   0%|          | 15/14850 [02:19<41:37:07, 10.10s/it]
#   0%|          | 16/14850 [02:29<41:04:42,  9.97s/it]
#   0%|          | 17/14850 [02:38<40:16:10,  9.77s/it]
#   0%|          | 18/14850 [02:48<40:12:26,  9.76s/it]
#   0%|          | 19/14850 [02:57<39:28:48,  9.58s/it]
#   0%|          | 20/14850 [03:07<39:21:06,  9.55s/it]
#   0%|          | 21/14850 [03:16<39:13:56,  9.52s/it]
#   0%|          | 22/14850 [03:26<39:13:27,  9.52s/it]
#   0%|          | 23/14850 [03:35<39:11:00,  9.51s/it]
#   0%|          | 24/14850 [03:45<39:09:52,  9.51s/it]
#   0%|          | 25/14850 [03:54<39:06:26,  9.50s/it]
#   0%|          | 26/14850 [04:03<38:56:23,  9.46s/it]
#   0%|          | 27/14850 [04:13<38:48:37,  9.43s/it]
#   0%|          | 28/14850 [04:22<38:43:23,  9.41s/it]
#   0%|          | 29/14850 [04:32<38:36:40,  9.38s/it]
#   0%|          | 30/14850 [04:41<38:31:44,  9.36s/it]
#   0%|          | 31/14850 [04:50<38:34:04,  9.37s/it]
#   0%|          | 32/14850 [05:00<38:33:12,  9.37s/it]
#   0%|          | 33/14850 [05:09<38:39:05,  9.39s/it]
#   0%|          | 34/14850 [05:18<38:42:42,  9.41s/it]
#   0%|          | 35/14850 [05:28<38:35:48,  9.38s/it]
#   0%|          | 36/14850 [05:37<38:34:07,  9.37s/it]
#   0%|          | 37/14850 [05:47<38:32:45,  9.37s/it]
#   0%|          | 38/14850 [05:56<38:40:33,  9.40s/it]
#   0%|          | 39/14850 [06:05<38:43:07,  9.41s/it]
#   0%|          | 40/14850 [06:15<38:49:08,  9.44s/it]
#   0%|          | 41/14850 [06:24<38:49:40,  9.44s/it]
#   0%|          | 42/14850 [06:34<38:43:53,  9.42s/it]
#   0%|          | 43/14850 [06:43<38:42:54,  9.41s/it]
#   0%|          | 44/14850 [06:53<38:42:25,  9.41s/it]
#   0%|          | 45/14850 [07:02<38:37:05,  9.39s/it]
#   0%|          | 46/14850 [07:11<38:42:04,  9.41s/it]
#   0%|          | 47/14850 [07:21<38:49:14,  9.44s/it]
#   0%|          | 48/14850 [07:30<38:41:47,  9.41s/it]
#   0%|          | 49/14850 [07:40<38:45:23,  9.43s/it]
#   0%|          | 50/14850 [07:49<38:43:22,  9.42s/it]
#   0%|          | 51/14850 [07:58<38:42:21,  9.42s/it]
#   0%|          | 52/14850 [08:08<38:41:27,  9.41s/it]
#   0%|          | 53/14850 [08:17<38:42:15,  9.42s/it]
#   0%|          | 54/14850 [08:27<38:47:37,  9.44s/it]
#   0%|          | 55/14850 [08:36<38:40:10,  9.41s/it]
#   0%|          | 56/14850 [08:46<38:45:36,  9.43s/it]
#   0%|          | 57/14850 [08:55<38:42:51,  9.42s/it]
#   0%|          | 58/14850 [09:04<38:47:36,  9.44s/it]
#   0%|          | 59/14850 [09:14<38:53:01,  9.46s/it]
#   0%|          | 60/14850 [09:23<38:53:15,  9.47s/it]
#   0%|          | 61/14850 [09:33<38:43:31,  9.43s/it]
#   0%|          | 62/14850 [09:42<38:38:04,  9.41s/it]
#   0%|          | 63/14850 [09:51<38:29:19,  9.37s/it]
#   0%|          | 64/14850 [10:01<38:29:31,  9.37s/it]
#   0%|          | 65/14850 [10:10<38:21:51,  9.34s/it]
#   0%|          | 66/14850 [10:20<38:27:49,  9.37s/it]
#   0%|          | 67/14850 [10:29<38:23:11,  9.35s/it]
#   0%|          | 68/14850 [10:38<38:19:31,  9.33s/it]
#   0%|          | 69/14850 [10:47<38:13:12,  9.31s/it]
#   0%|          | 70/14850 [10:57<38:07:25,  9.29s/it]
#   0%|          | 71/14850 [11:06<38:07:31,  9.29s/it]
#   0%|          | 72/14850 [11:15<38:19:21,  9.34s/it]
#   0%|          | 73/14850 [11:25<38:20:50,  9.34s/it]
#   0%|          | 74/14850 [11:34<38:19:03,  9.34s/it]
#   1%|          | 75/14850 [11:43<38:17:16,  9.33s/it]
#   1%|          | 76/14850 [11:53<38:07:35,  9.29s/it]
#   1%|          | 77/14850 [12:02<38:02:27,  9.27s/it]
#   1%|          | 78/14850 [12:11<38:02:49,  9.27s/it]
#   1%|          | 79/14850 [12:20<38:13:34,  9.32s/it]
#   1%|          | 80/14850 [12:30<38:12:00,  9.31s/it]
#   1%|          | 81/14850 [12:39<38:29:10,  9.38s/it]
#   1%|          | 82/14850 [12:49<38:24:24,  9.36s/it]
#   1%|          | 83/14850 [12:58<38:19:15,  9.34s/it]
#   1%|          | 84/14850 [13:07<38:12:04,  9.31s/it]
#   1%|          | 85/14850 [13:16<38:04:43,  9.28s/it]
#   1%|          | 86/14850 [13:26<38:17:22,  9.34s/it]
#   1%|          | 87/14850 [13:35<38:08:05,  9.30s/it]
#   1%|          | 88/14850 [13:44<37:59:21,  9.26s/it]
#   1%|          | 89/14850 [13:54<38:07:18,  9.30s/it]
#   1%|          | 90/14850 [14:03<38:09:05,  9.31s/it]
#   1%|          | 91/14850 [14:12<38:25:50,  9.37s/it]
#   1%|          | 92/14850 [14:22<38:18:41,  9.35s/it]
#   1%|          | 93/14850 [14:31<38:20:09,  9.35s/it]
#   1%|          | 94/14850 [14:40<38:13:23,  9.33s/it]
#   1%|          | 95/14850 [14:50<38:07:39,  9.30s/it]
#   1%|          | 96/14850 [14:59<38:16:38,  9.34s/it]
#   1%|          | 97/14850 [15:08<38:23:44,  9.37s/it]
#   1%|          | 98/14850 [15:18<38:21:15,  9.36s/it]
#   1%|          | 99/14850 [15:27<38:15:44,  9.34s/it]
#   1%|          | 100/14850 [15:36<38:13:55,  9.33s/it]
#   1%|          | 101/14850 [15:46<38:17:32,  9.35s/it]
#   1%|          | 102/14850 [15:55<38:15:30,  9.34s/it]
#   1%|          | 103/14850 [16:04<38:11:35,  9.32s/it]
#   1%|          | 104/14850 [16:14<38:11:25,  9.32s/it]
#   1%|          | 105/14850 [16:26<41:30:56, 10.14s/it]
#   1%|          | 106/14850 [16:35<40:37:10,  9.92s/it]
#   1%|          | 107/14850 [16:45<39:54:30,  9.74s/it]
#   1%|          | 108/14850 [16:54<39:27:36,  9.64s/it]
#   1%|          | 109/14850 [17:03<39:08:52,  9.56s/it]
#   1%|          | 110/14850 [17:13<38:50:30,  9.49s/it]
#   1%|          | 111/14850 [17:22<38:44:47,  9.46s/it]
#   1%|          | 112/14850 [17:31<38:37:00,  9.43s/it]
#   1%|          | 113/14850 [17:41<38:34:15,  9.42s/it]
#   1%|          | 114/14850 [17:50<38:43:04,  9.46s/it]
#   1%|          | 115/14850 [18:00<38:31:01,  9.41s/it]
#   1%|          | 116/14850 [18:09<38:22:27,  9.38s/it]
#   1%|          | 117/14850 [18:18<38:17:12,  9.36s/it]
#   1%|          | 118/14850 [18:28<38:13:51,  9.34s/it]
#   1%|          | 119/14850 [18:37<38:12:55,  9.34s/it]
#   1%|          | 120/14850 [18:46<38:15:38,  9.35s/it]
#   1%|          | 121/14850 [18:55<38:06:55,  9.32s/it]
#   1%|          | 122/14850 [19:05<38:16:01,  9.35s/it]
#   1%|          | 123/14850 [19:14<38:08:18,  9.32s/it]
#   1%|          | 124/14850 [19:24<38:14:54,  9.35s/it]
#   1%|          | 125/14850 [19:33<38:05:54,  9.31s/it]
#   1%|          | 126/14850 [19:42<38:05:28,  9.31s/it]
#   1%|          | 127/14850 [19:51<38:07:55,  9.32s/it]
#   1%|          | 128/14850 [20:01<38:04:27,  9.31s/it]
#   1%|          | 129/14850 [20:10<38:02:15,  9.30s/it]
#   1%|          | 130/14850 [20:19<38:09:04,  9.33s/it]
#   1%|          | 131/14850 [20:29<38:12:39,  9.35s/it]
#   1%|          | 132/14850 [20:38<38:08:48,  9.33s/it]
#   1%|          | 133/14850 [20:47<38:07:15,  9.32s/it]
#   1%|          | 134/14850 [20:57<38:04:21,  9.31s/it]
#   1%|          | 135/14850 [21:06<37:54:28,  9.27s/it]
#   1%|          | 136/14850 [21:15<37:49:07,  9.25s/it]
#   1%|          | 137/14850 [21:24<37:40:33,  9.22s/it]
#   1%|          | 138/14850 [21:34<37:54:05,  9.27s/it]
#   1%|          | 139/14850 [21:43<37:50:56,  9.26s/it]
#   1%|          | 140/14850 [21:52<37:48:56,  9.25s/it]
#   1%|          | 141/14850 [22:01<37:47:05,  9.25s/it]
#   1%|          | 142/14850 [22:11<37:40:49,  9.22s/it]
#   1%|          | 143/14850 [22:20<37:38:48,  9.22s/it]
#   1%|          | 144/14850 [22:29<37:39:36,  9.22s/it]
#   1%|          | 145/14850 [22:38<37:49:16,  9.26s/it]
#   1%|          | 146/14850 [22:48<37:56:50,  9.29s/it]
#   1%|          | 147/14850 [22:57<38:06:22,  9.33s/it]
#   1%|          | 148/14850 [23:06<38:03:44,  9.32s/it]
#   1%|          | 149/14850 [23:16<38:05:20,  9.33s/it]
#   1%|          | 150/14850 [23:25<38:00:54,  9.31s/it]
#   1%|          | 151/14850 [23:34<38:05:17,  9.33s/it]
#   1%|          | 152/14850 [23:44<38:13:17,  9.36s/it]
#   1%|          | 153/14850 [23:53<38:09:03,  9.35s/it]
#   1%|          | 154/14850 [24:02<38:12:24,  9.36s/it]
#   1%|          | 155/14850 [24:12<38:11:38,  9.36s/it]
#   1%|          | 156/14850 [24:21<38:06:53,  9.34s/it]
#   1%|          | 157/14850 [24:31<38:12:00,  9.36s/it]
#   1%|          | 158/14850 [24:40<38:16:39,  9.38s/it]
#   1%|          | 159/14850 [24:49<38:19:48,  9.39s/it]
#   1%|          | 160/14850 [24:59<38:16:52,  9.38s/it]
#   1%|          | 161/14850 [25:08<38:14:59,  9.37s/it]
#   1%|          | 162/14850 [25:17<38:13:06,  9.37s/it]
#   1%|          | 163/14850 [25:27<38:13:41,  9.37s/it]
#   1%|          | 164/14850 [25:36<38:07:59,  9.35s/it]
#   1%|          | 165/14850 [25:45<38:08:00,  9.35s/it]
#   1%|          | 166/14850 [25:55<38:09:57,  9.36s/it]
#   1%|          | 167/14850 [26:04<38:06:42,  9.34s/it]
#   1%|          | 168/14850 [26:14<38:15:13,  9.38s/it]
#   1%|          | 169/14850 [26:23<38:10:51,  9.36s/it]
#   1%|          | 170/14850 [26:35<41:52:14, 10.27s/it]
#   1%|          | 171/14850 [26:45<40:52:00, 10.02s/it]
#   1%|          | 172/14850 [26:54<39:58:53,  9.81s/it]
#   1%|          | 173/14850 [27:03<39:20:13,  9.65s/it]
#   1%|          | 174/14850 [27:13<38:47:19,  9.51s/it]
#   1%|          | 175/14850 [27:22<38:30:19,  9.45s/it]
#   1%|          | 176/14850 [27:31<38:19:00,  9.40s/it]
#   1%|          | 177/14850 [27:41<38:17:08,  9.39s/it]
#   1%|          | 178/14850 [27:50<38:15:35,  9.39s/it]
#   1%|          | 179/14850 [27:59<38:10:13,  9.37s/it]
#   1%|          | 180/14850 [28:09<38:03:56,  9.34s/it]
#   1%|          | 181/14850 [28:18<37:59:59,  9.33s/it]
#   1%|          | 182/14850 [28:27<37:53:23,  9.30s/it]
#   1%|          | 183/14850 [28:37<38:05:24,  9.35s/it]
#   1%|          | 184/14850 [28:46<38:09:18,  9.37s/it]
#   1%|          | 185/14850 [28:55<38:12:46,  9.38s/it]
#   1%|▏         | 186/14850 [29:05<38:14:04,  9.39s/it]
#   1%|▏         | 187/14850 [29:14<38:11:47,  9.38s/it]
#   1%|▏         | 188/14850 [29:23<38:11:28,  9.38s/it]
#   1%|▏         | 189/14850 [29:33<38:05:55,  9.36s/it]
#   1%|▏         | 190/14850 [29:42<38:08:12,  9.37s/it]
#   1%|▏         | 191/14850 [29:52<38:09:31,  9.37s/it]
#   1%|▏         | 192/14850 [30:01<38:08:18,  9.37s/it]
#   1%|▏         | 193/14850 [30:10<38:04:10,  9.35s/it]
#   1%|▏         | 194/14850 [30:20<38:06:37,  9.36s/it]
#   1%|▏         | 195/14850 [30:29<38:02:11,  9.34s/it]
#   1%|▏         | 196/14850 [30:38<37:58:58,  9.33s/it]
#   1%|▏         | 197/14850 [30:48<37:57:22,  9.33s/it]
#   1%|▏         | 198/14850 [30:57<37:56:25,  9.32s/it]
#   1%|▏         | 199/14850 [31:06<37:56:22,  9.32s/it]
#   1%|▏         | 200/14850 [31:15<37:52:28,  9.31s/it]
#   1%|▏         | 201/14850 [31:25<37:57:52,  9.33s/it]
#   1%|▏         | 202/14850 [31:34<37:59:02,  9.34s/it]
#   1%|▏         | 203/14850 [31:43<37:52:10,  9.31s/it]
#   1%|▏         | 204/14850 [31:53<37:53:56,  9.32s/it]
#   1%|▏         | 205/14850 [32:02<38:01:35,  9.35s/it]
#   1%|▏         | 206/14850 [32:11<37:54:09,  9.32s/it]
#   1%|▏         | 207/14850 [32:21<37:51:41,  9.31s/it]
#   1%|▏         | 208/14850 [32:30<37:47:32,  9.29s/it]
#   1%|▏         | 209/14850 [32:39<37:48:40,  9.30s/it]
#   1%|▏         | 210/14850 [32:49<37:46:20,  9.29s/it]
#   1%|▏         | 211/14850 [32:58<37:49:27,  9.30s/it]
#   1%|▏         | 212/14850 [33:07<37:40:42,  9.27s/it]
#   1%|▏         | 213/14850 [33:16<37:35:17,  9.24s/it]
#   1%|▏         | 214/14850 [33:25<37:35:47,  9.25s/it]
#   1%|▏         | 215/14850 [33:35<37:37:11,  9.25s/it]
#   1%|▏         | 216/14850 [33:44<37:41:20,  9.27s/it]
#   1%|▏         | 217/14850 [33:53<37:43:58,  9.28s/it]
#   1%|▏         | 218/14850 [34:03<37:40:13,  9.27s/it]
#   1%|▏         | 219/14850 [34:12<37:36:05,  9.25s/it]
#   1%|▏         | 220/14850 [34:21<37:36:41,  9.26s/it]
#   1%|▏         | 221/14850 [34:30<37:45:02,  9.29s/it]
#   1%|▏         | 222/14850 [34:40<37:53:38,  9.33s/it]
#   2%|▏         | 223/14850 [34:49<37:51:53,  9.32s/it]
#   2%|▏         | 224/14850 [34:58<37:48:32,  9.31s/it]
#   2%|▏         | 225/14850 [35:08<37:51:23,  9.32s/it]
#   2%|▏         | 226/14850 [35:17<37:55:37,  9.34s/it]
#   2%|▏         | 227/14850 [35:26<37:55:33,  9.34s/it]
#   2%|▏         | 228/14850 [35:36<37:52:23,  9.32s/it]
#   2%|▏         | 229/14850 [35:45<37:53:38,  9.33s/it]
#   2%|▏         | 230/14850 [35:54<37:54:14,  9.33s/it]
#   2%|▏         | 231/14850 [36:04<38:03:01,  9.37s/it]
#   2%|▏         | 232/14850 [36:13<37:54:15,  9.33s/it]
#   2%|▏         | 233/14850 [36:22<37:49:50,  9.32s/it]
#   2%|▏         | 234/14850 [36:32<37:47:02,  9.31s/it]
#   2%|▏         | 235/14850 [36:44<40:57:25, 10.09s/it]
#   2%|▏         | 236/14850 [36:53<39:54:10,  9.83s/it]
#   2%|▏         | 237/14850 [37:02<39:12:59,  9.66s/it]
#   2%|▏         | 238/14850 [37:11<38:37:23,  9.52s/it]
#   2%|▏         | 239/14850 [37:21<38:21:00,  9.45s/it]
#   2%|▏         | 240/14850 [37:30<37:59:27,  9.36s/it]
#   2%|▏         | 241/14850 [37:39<37:46:01,  9.31s/it]
#   2%|▏         | 242/14850 [37:48<37:36:41,  9.27s/it]
#   2%|▏         | 243/14850 [37:57<37:37:48,  9.27s/it]
#   2%|▏         | 244/14850 [38:07<37:38:32,  9.28s/it]
#   2%|▏         | 245/14850 [38:16<37:39:33,  9.28s/it]
#   2%|▏         | 246/14850 [38:25<37:40:22,  9.29s/it]
#   2%|▏         | 247/14850 [38:35<37:36:19,  9.27s/it]
#   2%|▏         | 248/14850 [38:44<37:37:24,  9.28s/it]
#   2%|▏         | 249/14850 [38:53<37:38:09,  9.28s/it]
#   2%|▏         | 250/14850 [39:02<37:38:47,  9.28s/it]
#   2%|▏         | 251/14850 [39:12<37:36:19,  9.27s/it]
#   2%|▏         | 252/14850 [39:21<37:40:46,  9.29s/it]
#   2%|▏         | 253/14850 [39:30<37:45:43,  9.31s/it]
#   2%|▏         | 254/14850 [39:40<37:52:25,  9.34s/it]
#   2%|▏         | 255/14850 [39:49<37:51:08,  9.34s/it]
#   2%|▏         | 256/14850 [39:58<37:46:35,  9.32s/it]
#   2%|▏         | 257/14850 [40:08<37:41:04,  9.30s/it]
#   2%|▏         | 258/14850 [40:17<37:39:00,  9.29s/it]
#   2%|▏         | 259/14850 [40:26<37:40:15,  9.29s/it]
#   2%|▏         | 260/14850 [40:35<37:37:55,  9.29s/it]
#   2%|▏         | 261/14850 [40:45<37:34:20,  9.27s/it]
#   2%|▏         | 262/14850 [40:54<37:30:33,  9.26s/it]
#   2%|▏         | 263/14850 [41:03<37:24:59,  9.23s/it]
#   2%|▏         | 264/14850 [41:12<37:25:50,  9.24s/it]
#   2%|▏         | 265/14850 [41:22<37:23:42,  9.23s/it]
#   2%|▏         | 266/14850 [41:31<37:24:35,  9.23s/it]
#   2%|▏         | 267/14850 [41:40<37:21:16,  9.22s/it]
#   2%|▏         | 268/14850 [41:49<37:18:40,  9.21s/it]
#   2%|▏         | 269/14850 [41:58<37:26:02,  9.24s/it]
#   2%|▏         | 270/14850 [42:08<37:33:24,  9.27s/it]
#   2%|▏         | 271/14850 [42:17<37:31:37,  9.27s/it]
#   2%|▏         | 272/14850 [42:26<37:36:16,  9.29s/it]
#   2%|▏         | 273/14850 [42:36<37:32:12,  9.27s/it]
#   2%|▏         | 274/14850 [42:45<37:23:18,  9.23s/it]
#   2%|▏         | 275/14850 [42:54<37:24:30,  9.24s/it]
#   2%|▏         | 276/14850 [43:03<37:24:59,  9.24s/it]
#   2%|▏         | 277/14850 [43:13<37:27:10,  9.25s/it]
#   2%|▏         | 278/14850 [43:22<37:31:56,  9.27s/it]
#   2%|▏         | 279/14850 [43:31<37:28:19,  9.26s/it]
#   2%|▏         | 280/14850 [43:40<37:34:52,  9.29s/it]
#   2%|▏         | 281/14850 [43:50<37:28:52,  9.26s/it]
#   2%|▏         | 282/14850 [43:59<37:35:24,  9.29s/it]
#   2%|▏         | 283/14850 [44:08<37:40:24,  9.31s/it]
#   2%|▏         | 284/14850 [44:18<37:37:04,  9.30s/it]
#   2%|▏         | 285/14850 [44:27<37:44:15,  9.33s/it]
#   2%|▏         | 286/14850 [44:36<37:45:21,  9.33s/it]
#   2%|▏         | 287/14850 [44:46<37:39:40,  9.31s/it]
#   2%|▏         | 288/14850 [44:55<37:33:32,  9.29s/it]
#   2%|▏         | 289/14850 [45:04<37:31:28,  9.28s/it]
#   2%|▏         | 290/14850 [45:13<37:25:21,  9.25s/it]
#   2%|▏         | 291/14850 [45:22<37:05:48,  9.17s/it]
#   2%|▏         | 292/14850 [45:31<36:48:19,  9.10s/it]
#   2%|▏         | 293/14850 [45:40<36:26:36,  9.01s/it]
#   2%|▏         | 294/14850 [45:49<36:11:33,  8.95s/it]
#   2%|▏         | 295/14850 [45:58<36:01:49,  8.91s/it]
#   2%|▏         | 296/14850 [46:06<35:45:08,  8.84s/it]
#   2%|▏         | 297/14850 [46:15<35:32:11,  8.79s/it]
#   2%|▏         | 298/14850 [46:24<35:21:57,  8.75s/it]
#   2%|▏         | 299/14850 [46:32<35:00:42,  8.66s/it]
#   2%|▏         | 300/14850 [46:41<35:07:35,  8.69s/it]
#   2%|▏         | 301/14850 [46:51<37:05:36,  9.18s/it]
#   2%|▏         | 302/14850 [47:00<36:25:10,  9.01s/it]
#   2%|▏         | 303/14850 [47:08<35:29:09,  8.78s/it]
#   2%|▏         | 304/14850 [47:16<34:57:32,  8.65s/it]
#   2%|▏         | 305/14850 [47:25<34:26:04,  8.52s/it]
#   2%|▏         | 306/14850 [47:33<34:08:48,  8.45s/it]
#   2%|▏         | 307/14850 [47:41<33:53:10,  8.39s/it]
#   2%|▏         | 308/14850 [47:49<33:35:03,  8.31s/it]
#   2%|▏         | 309/14850 [47:58<33:25:14,  8.27s/it]
#   2%|▏         | 310/14850 [48:06<33:39:35,  8.33s/it]
#   2%|▏         | 311/14850 [48:14<33:16:57,  8.24s/it]
#   2%|▏         | 312/14850 [48:22<33:04:42,  8.19s/it]
#   2%|▏         | 313/14850 [48:30<33:15:06,  8.23s/it]
#   2%|▏         | 314/14850 [48:39<33:09:13,  8.21s/it]
#   2%|▏         | 315/14850 [48:47<33:00:43,  8.18s/it]
#   2%|▏         | 316/14850 [48:55<32:58:49,  8.17s/it]
#   2%|▏         | 317/14850 [49:03<32:46:23,  8.12s/it]
#   2%|▏         | 318/14850 [49:11<32:40:47,  8.10s/it]
#   2%|▏         | 319/14850 [49:19<32:42:16,  8.10s/it]
#   2%|▏         | 320/14850 [49:27<32:35:59,  8.08s/it]
#   2%|▏         | 321/14850 [49:35<32:30:25,  8.05s/it]
#   2%|▏         | 322/14850 [49:43<32:27:13,  8.04s/it]
#   2%|▏         | 323/14850 [49:51<32:20:36,  8.02s/it]
#   2%|▏         | 324/14850 [49:59<32:17:33,  8.00s/it]
#   2%|▏         | 325/14850 [50:07<32:19:36,  8.01s/it]
#   2%|▏         | 326/14850 [50:15<32:09:19,  7.97s/it]
#   2%|▏         | 327/14850 [50:23<32:11:10,  7.98s/it]
#   2%|▏         | 328/14850 [50:31<32:20:46,  8.02s/it]
#   2%|▏         | 329/14850 [50:39<32:13:17,  7.99s/it]
#   2%|▏         | 330/14850 [50:47<32:09:14,  7.97s/it]
#   2%|▏         | 331/14850 [50:55<32:12:14,  7.99s/it]
#   2%|▏         | 332/14850 [51:03<32:11:37,  7.98s/it]
#   2%|▏         | 333/14850 [51:11<31:54:09,  7.91s/it]
#   2%|▏         | 334/14850 [51:18<31:44:49,  7.87s/it]
#   2%|▏         | 335/14850 [51:26<31:30:42,  7.82s/it]
#   2%|▏         | 336/14850 [51:33<30:47:17,  7.64s/it]
#   2%|▏         | 337/14850 [51:40<30:19:29,  7.52s/it]
#   2%|▏         | 338/14850 [51:48<30:05:46,  7.47s/it]
#   2%|▏         | 339/14850 [51:55<29:26:33,  7.30s/it]
#   2%|▏         | 340/14850 [52:02<29:08:37,  7.23s/it]
#   2%|▏         | 341/14850 [52:08<28:18:36,  7.02s/it]
#   2%|▏         | 342/14850 [52:15<27:46:26,  6.89s/it]
#   2%|▏         | 343/14850 [52:22<27:38:41,  6.86s/it]
#   2%|▏         | 344/14850 [52:28<27:18:35,  6.78s/it]
#   2%|▏         | 345/14850 [52:35<26:51:38,  6.67s/it]
#   2%|▏         | 346/14850 [52:41<26:50:34,  6.66s/it]
#   2%|▏         | 347/14850 [52:48<26:46:37,  6.65s/it]
#   2%|▏         | 348/14850 [52:55<26:40:37,  6.62s/it]
#   2%|▏         | 349/14850 [53:01<26:42:03,  6.63s/it]
#   2%|▏         | 350/14850 [53:08<26:51:35,  6.67s/it]
#   2%|▏         | 351/14850 [53:15<27:02:13,  6.71s/it]
#   2%|▏         | 352/14850 [53:23<28:38:44,  7.11s/it]
#   2%|▏         | 353/14850 [53:29<28:05:28,  6.98s/it]
#   2%|▏         | 354/14850 [53:36<27:34:05,  6.85s/it]
#   2%|▏         | 355/14850 [53:43<27:24:31,  6.81s/it]
#   2%|▏         | 356/14850 [53:50<27:22:18,  6.80s/it]
#   2%|▏         | 357/14850 [53:56<27:04:11,  6.72s/it]
#   2%|▏         | 358/14850 [54:03<27:03:01,  6.72s/it]
#   2%|▏         | 359/14850 [54:09<26:40:54,  6.63s/it]
#   2%|▏         | 360/14850 [54:15<26:10:55,  6.50s/it]
#   2%|▏         | 361/14850 [54:22<25:58:35,  6.45s/it]
#   2%|▏         | 362/14850 [54:28<25:53:19,  6.43s/it]
#   2%|▏         | 363/14850 [54:34<25:44:38,  6.40s/it]
#   2%|▏         | 364/14850 [54:41<25:38:54,  6.37s/it]
#   2%|▏         | 365/14850 [54:48<26:18:49,  6.54s/it]
#   2%|▏         | 366/14850 [54:54<25:54:41,  6.44s/it]
#   2%|▏         | 367/14850 [55:00<25:37:25,  6.37s/it]
#   2%|▏         | 368/14850 [55:06<25:17:41,  6.29s/it]
#   2%|▏         | 369/14850 [55:12<25:07:36,  6.25s/it]
#   2%|▏         | 370/14850 [55:18<25:00:01,  6.22s/it]
#   2%|▏         | 371/14850 [55:25<25:25:52,  6.32s/it]
#   3%|▎         | 372/14850 [55:31<25:21:29,  6.31s/it]
#   3%|▎         | 373/14850 [55:38<25:19:18,  6.30s/it]
#   3%|▎         | 374/14850 [55:44<25:18:25,  6.29s/it]
#   3%|▎         | 375/14850 [55:50<25:16:20,  6.29s/it]
#   3%|▎         | 376/14850 [55:56<25:18:06,  6.29s/it]
#   3%|▎         | 377/14850 [56:03<26:11:31,  6.51s/it]
#   3%|▎         | 378/14850 [56:10<25:56:53,  6.45s/it]
#   3%|▎         | 379/14850 [56:16<25:46:08,  6.41s/it]
#   3%|▎         | 380/14850 [56:22<25:41:36,  6.39s/it]
#   3%|▎         | 381/14850 [56:29<25:43:35,  6.40s/it]
#   3%|▎         | 382/14850 [56:35<25:46:06,  6.41s/it]
#   3%|▎         | 383/14850 [56:42<25:47:11,  6.42s/it]
#   3%|▎         | 384/14850 [56:48<25:44:51,  6.41s/it]
#   3%|▎         | 385/14850 [56:55<25:53:35,  6.44s/it]
#   3%|▎         | 386/14850 [57:03<28:42:06,  7.14s/it]
#   3%|▎         | 387/14850 [57:10<27:45:11,  6.91s/it]
#   3%|▎         | 388/14850 [57:16<27:02:45,  6.73s/it]
#   3%|▎         | 389/14850 [57:22<26:24:41,  6.58s/it]
#   3%|▎         | 390/14850 [57:29<26:05:44,  6.50s/it]
#   3%|▎         | 391/14850 [57:35<25:40:36,  6.39s/it]
#   3%|▎         | 392/14850 [57:41<25:36:53,  6.38s/it]
#   3%|▎         | 393/14850 [57:47<25:01:05,  6.23s/it]
#   3%|▎         | 394/14850 [57:53<24:41:24,  6.15s/it]
#   3%|▎         | 395/14850 [57:59<24:19:58,  6.06s/it]
#   3%|▎         | 396/14850 [58:05<24:11:52,  6.03s/it]
#   3%|▎         | 397/14850 [58:11<24:05:59,  6.00s/it]
#   3%|▎         | 398/14850 [58:17<24:01:04,  5.98s/it]
#   3%|▎         | 399/14850 [58:23<24:01:07,  5.98s/it]
#   3%|▎         | 400/14850 [58:29<24:04:32,  6.00s/it]
#   3%|▎         | 401/14850 [58:35<24:00:20,  5.98s/it]
#   3%|▎         | 402/14850 [58:40<23:50:52,  5.94s/it]
#   3%|▎         | 403/14850 [58:46<23:49:17,  5.94s/it]
#   3%|▎         | 404/14850 [58:52<23:51:00,  5.94s/it]
#   3%|▎         | 405/14850 [58:58<23:52:39,  5.95s/it]
#   3%|▎         | 406/14850 [59:04<23:54:47,  5.96s/it]
#   3%|▎         | 407/14850 [59:11<24:20:16,  6.07s/it]
#   3%|▎         | 408/14850 [59:17<24:07:34,  6.01s/it]
#   3%|▎         | 409/14850 [59:22<24:01:19,  5.99s/it]
#   3%|▎         | 410/14850 [59:28<23:54:40,  5.96s/it]
#   3%|▎         | 411/14850 [59:34<23:49:36,  5.94s/it]
#   3%|▎         | 412/14850 [59:40<23:50:39,  5.95s/it]
#   3%|▎         | 413/14850 [59:46<23:47:26,  5.93s/it]
#   3%|▎         | 414/14850 [59:52<23:50:53,  5.95s/it]
#   3%|▎         | 415/14850 [59:58<23:56:17,  5.97s/it]
#   3%|▎         | 416/14850 [1:00:04<24:18:59,  6.06s/it]
#   3%|▎         | 417/14850 [1:00:11<24:33:25,  6.13s/it]
#   3%|▎         | 418/14850 [1:00:17<25:12:04,  6.29s/it]
#   3%|▎         | 419/14850 [1:00:23<25:02:20,  6.25s/it]
#   3%|▎         | 420/14850 [1:00:30<24:53:13,  6.21s/it]
#   3%|▎         | 421/14850 [1:00:36<24:53:01,  6.21s/it]
#   3%|▎         | 422/14850 [1:00:42<24:57:30,  6.23s/it]
#   3%|▎         | 423/14850 [1:00:48<24:52:50,  6.21s/it]
#   3%|▎         | 424/14850 [1:00:54<24:45:56,  6.18s/it]
#   3%|▎         | 425/14850 [1:01:00<24:35:50,  6.14s/it]
#   3%|▎         | 426/14850 [1:01:07<24:38:43,  6.15s/it]
#   3%|▎         | 427/14850 [1:01:13<24:42:10,  6.17s/it]
#   3%|▎         | 428/14850 [1:01:19<24:47:46,  6.19s/it]
#   3%|▎         | 429/14850 [1:01:26<25:09:38,  6.28s/it]
#   3%|▎         | 430/14850 [1:01:32<25:25:56,  6.35s/it]
#   3%|▎         | 431/14850 [1:01:38<25:28:08,  6.36s/it]
#   3%|▎         | 432/14850 [1:01:45<25:35:37,  6.39s/it]
#   3%|▎         | 433/14850 [1:01:51<25:35:11,  6.39s/it]
#   3%|▎         | 434/14850 [1:01:58<25:31:05,  6.37s/it]
#   3%|▎         | 435/14850 [1:02:04<25:23:56,  6.34s/it]
#   3%|▎         | 436/14850 [1:02:10<25:20:46,  6.33s/it]
#   3%|▎         | 437/14850 [1:02:16<25:06:38,  6.27s/it]
#   3%|▎         | 438/14850 [1:02:23<25:04:03,  6.26s/it]
#   3%|▎         | 439/14850 [1:02:29<25:08:11,  6.28s/it]
#   3%|▎         | 440/14850 [1:02:35<25:06:45,  6.27s/it]
#   3%|▎         | 441/14850 [1:02:41<25:13:55,  6.30s/it]
#   3%|▎         | 442/14850 [1:02:48<25:13:41,  6.30s/it]
#   3%|▎         | 443/14850 [1:02:54<25:19:20,  6.33s/it]
#   3%|▎         | 444/14850 [1:03:00<25:17:06,  6.32s/it]
#   3%|▎         | 445/14850 [1:03:07<25:20:27,  6.33s/it]
#   3%|▎         | 446/14850 [1:03:13<25:30:46,  6.38s/it]
#   3%|▎         | 447/14850 [1:03:20<25:42:39,  6.43s/it]
#   3%|▎         | 448/14850 [1:03:26<25:50:37,  6.46s/it]
#   3%|▎         | 449/14850 [1:03:33<25:48:39,  6.45s/it]
#   3%|▎         | 450/14850 [1:03:39<25:42:00,  6.43s/it]
#   3%|▎         | 451/14850 [1:03:46<25:40:42,  6.42s/it]
#   3%|▎         | 452/14850 [1:03:52<25:30:58,  6.38s/it]
#   3%|▎         | 453/14850 [1:03:58<25:24:02,  6.35s/it]
#   3%|▎         | 454/14850 [1:04:05<25:35:17,  6.40s/it]
#   3%|▎         | 455/14850 [1:04:11<25:43:42,  6.43s/it]
#   3%|▎         | 456/14850 [1:04:18<25:42:15,  6.43s/it]
#   3%|▎         | 457/14850 [1:04:24<25:45:59,  6.44s/it]
#   3%|▎         | 458/14850 [1:04:31<25:44:31,  6.44s/it]
#   3%|▎         | 459/14850 [1:04:37<25:45:55,  6.45s/it]
#   3%|▎         | 460/14850 [1:04:43<25:49:02,  6.46s/it]
#   3%|▎         | 461/14850 [1:04:50<25:49:01,  6.46s/it]
#   3%|▎         | 462/14850 [1:04:56<25:41:52,  6.43s/it]
#   3%|▎         | 463/14850 [1:05:03<25:44:50,  6.44s/it]
#   3%|▎         | 464/14850 [1:05:09<25:52:54,  6.48s/it]
#   3%|▎         | 465/14850 [1:05:16<25:47:56,  6.46s/it]
#   3%|▎         | 466/14850 [1:05:22<25:52:29,  6.48s/it]
#   3%|▎         | 467/14850 [1:05:29<25:54:21,  6.48s/it]
#   3%|▎         | 468/14850 [1:05:35<25:48:57,  6.46s/it]
#   3%|▎         | 469/14850 [1:05:42<25:42:33,  6.44s/it]
#   3%|▎         | 470/14850 [1:05:48<25:42:46,  6.44s/it]
#   3%|▎         | 471/14850 [1:05:55<25:53:25,  6.48s/it]
#   3%|▎         | 472/14850 [1:06:01<26:03:23,  6.52s/it]
#   3%|▎         | 473/14850 [1:06:08<26:11:22,  6.56s/it]
#   3%|▎         | 474/14850 [1:06:14<26:09:52,  6.55s/it]
#   3%|▎         | 475/14850 [1:06:21<26:13:36,  6.57s/it]
#   3%|▎         | 476/14850 [1:06:28<26:21:58,  6.60s/it]
#   3%|▎         | 477/14850 [1:06:34<26:14:37,  6.57s/it]
#   3%|▎         | 478/14850 [1:06:41<26:09:20,  6.55s/it]
#   3%|▎         | 479/14850 [1:06:47<26:06:23,  6.54s/it]
#   3%|▎         | 480/14850 [1:06:54<26:11:50,  6.56s/it]
#   3%|▎         | 481/14850 [1:07:00<26:17:33,  6.59s/it]
#   3%|▎         | 482/14850 [1:07:07<26:32:35,  6.65s/it]
#   3%|▎         | 483/14850 [1:07:16<28:28:42,  7.14s/it]
#   3%|▎         | 484/14850 [1:07:22<27:45:10,  6.95s/it]
#   3%|▎         | 485/14850 [1:07:29<27:13:24,  6.82s/it]
#   3%|▎         | 486/14850 [1:07:35<26:48:43,  6.72s/it]
#   3%|▎         | 487/14850 [1:07:42<26:40:55,  6.69s/it]
#   3%|▎         | 488/14850 [1:07:48<26:29:24,  6.64s/it]
#   3%|▎         | 489/14850 [1:07:55<26:28:07,  6.64s/it]
#   3%|▎         | 490/14850 [1:08:02<26:34:52,  6.66s/it]
#   3%|▎         | 491/14850 [1:08:08<26:31:56,  6.65s/it]
#   3%|▎         | 492/14850 [1:08:15<26:22:02,  6.61s/it]
#   3%|▎         | 493/14850 [1:08:21<26:22:15,  6.61s/it]
#   3%|▎         | 494/14850 [1:08:28<26:21:22,  6.61s/it]
#   3%|▎         | 495/14850 [1:08:34<26:18:25,  6.60s/it]
#   3%|▎         | 496/14850 [1:08:41<26:22:13,  6.61s/it]
#   3%|▎         | 497/14850 [1:08:48<26:20:56,  6.61s/it]
#   3%|▎         | 498/14850 [1:08:54<26:19:12,  6.60s/it]
#   3%|▎         | 499/14850 [1:09:01<26:19:35,  6.60s/it]
#   3%|▎         | 500/14850 [1:09:08<26:20:39,  6.61s/it]
#   3%|▎         | 501/14850 [1:09:14<26:21:23,  6.61s/it]
#   3%|▎         | 502/14850 [1:09:21<26:30:38,  6.65s/it]
#   3%|▎         | 503/14850 [1:09:27<26:26:53,  6.64s/it]
#   3%|▎         | 504/14850 [1:09:34<26:21:36,  6.61s/it]
#   3%|▎         | 505/14850 [1:09:41<26:19:01,  6.60s/it]
#   3%|▎         | 506/14850 [1:09:47<26:15:25,  6.59s/it]
#   3%|▎         | 507/14850 [1:09:54<26:14:55,  6.59s/it]
#   3%|▎         | 508/14850 [1:10:00<26:17:24,  6.60s/it]
#   3%|▎         | 509/14850 [1:10:07<26:27:21,  6.64s/it]
#   3%|▎         | 510/14850 [1:10:14<26:30:41,  6.66s/it]
#   3%|▎         | 511/14850 [1:10:20<26:23:56,  6.63s/it]
#   3%|▎         | 512/14850 [1:10:27<26:17:42,  6.60s/it]
#   3%|▎         | 513/14850 [1:10:33<26:11:37,  6.58s/it]
#   3%|▎         | 514/14850 [1:10:40<26:11:17,  6.58s/it]
#   3%|▎         | 515/14850 [1:10:47<26:07:34,  6.56s/it]
#   3%|▎         | 516/14850 [1:10:53<26:10:43,  6.57s/it]
#   3%|▎         | 517/14850 [1:11:00<26:13:29,  6.59s/it]
#   3%|▎         | 518/14850 [1:11:06<26:16:53,  6.60s/it]
#   3%|▎         | 519/14850 [1:11:13<26:15:53,  6.60s/it]
#   4%|▎         | 520/14850 [1:11:20<26:11:36,  6.58s/it]
#   4%|▎         | 521/14850 [1:11:26<26:12:05,  6.58s/it]
#   4%|▎         | 522/14850 [1:11:33<26:10:25,  6.58s/it]
#   4%|▎         | 523/14850 [1:11:39<26:12:31,  6.59s/it]
#   4%|▎         | 524/14850 [1:11:46<26:09:30,  6.57s/it]
#   4%|▎         | 525/14850 [1:11:52<26:12:58,  6.59s/it]
#   4%|▎         | 526/14850 [1:11:59<26:16:17,  6.60s/it]
#   4%|▎         | 527/14850 [1:12:06<26:17:21,  6.61s/it]
#   4%|▎         | 528/14850 [1:12:12<26:18:55,  6.61s/it]
#   4%|▎         | 529/14850 [1:12:19<26:20:25,  6.62s/it]
#   4%|▎         | 530/14850 [1:12:26<26:17:43,  6.61s/it]
#   4%|▎         | 531/14850 [1:12:32<26:15:26,  6.60s/it]
#   4%|▎         | 532/14850 [1:12:39<26:16:35,  6.61s/it]
#   4%|▎         | 533/14850 [1:12:45<26:16:33,  6.61s/it]
#   4%|▎         | 534/14850 [1:12:52<26:14:34,  6.60s/it]
#   4%|▎         | 535/14850 [1:12:59<26:19:16,  6.62s/it]
#   4%|▎         | 536/14850 [1:13:05<26:19:19,  6.62s/it]
#   4%|▎         | 537/14850 [1:13:12<26:21:35,  6.63s/it]
#   4%|▎         | 538/14850 [1:13:19<26:26:07,  6.65s/it]
#   4%|▎         | 539/14850 [1:13:25<26:31:30,  6.67s/it]
#   4%|▎         | 540/14850 [1:13:32<26:36:30,  6.69s/it]
#   4%|▎         | 541/14850 [1:13:39<26:31:39,  6.67s/it]
#   4%|▎         | 542/14850 [1:13:45<26:29:31,  6.67s/it]
#   4%|▎         | 543/14850 [1:13:52<26:24:14,  6.64s/it]
#   4%|▎         | 544/14850 [1:13:59<26:24:01,  6.64s/it]
#   4%|▎         | 545/14850 [1:14:05<26:25:58,  6.65s/it]
#   4%|▎         | 546/14850 [1:14:12<26:22:10,  6.64s/it]
#   4%|▎         | 547/14850 [1:14:18<26:21:28,  6.63s/it]
#   4%|▎         | 548/14850 [1:14:25<26:18:37,  6.62s/it]
#   4%|▎         | 549/14850 [1:14:32<26:16:33,  6.61s/it]
#   4%|▎         | 550/14850 [1:14:38<26:16:06,  6.61s/it]
#   4%|▎         | 551/14850 [1:14:45<26:17:40,  6.62s/it]
#   4%|▎         | 552/14850 [1:14:52<26:18:22,  6.62s/it]
#   4%|▎         | 553/14850 [1:14:58<26:11:54,  6.60s/it]
#   4%|▎         | 554/14850 [1:15:05<26:15:29,  6.61s/it]
#   4%|▎         | 555/14850 [1:15:11<26:14:31,  6.61s/it]
#   4%|▎         | 556/14850 [1:15:18<26:11:52,  6.60s/it]
#   4%|▍         | 557/14850 [1:15:24<26:10:40,  6.59s/it]
#   4%|▍         | 558/14850 [1:15:31<26:11:39,  6.60s/it]
#   4%|▍         | 559/14850 [1:15:38<26:26:51,  6.66s/it]
#   4%|▍         | 560/14850 [1:15:45<26:23:12,  6.65s/it]
#   4%|▍         | 561/14850 [1:15:51<26:18:37,  6.63s/it]
#   4%|▍         | 562/14850 [1:15:58<26:16:10,  6.62s/it]
#   4%|▍         | 563/14850 [1:16:04<26:14:21,  6.61s/it]
#   4%|▍         | 564/14850 [1:16:11<26:07:52,  6.58s/it]
#   4%|▍         | 565/14850 [1:16:17<26:14:06,  6.61s/it]
#   4%|▍         | 566/14850 [1:16:24<26:16:50,  6.62s/it]
#   4%|▍         | 567/14850 [1:16:31<26:08:58,  6.59s/it]
#   4%|▍         | 568/14850 [1:16:37<26:04:43,  6.57s/it]
#   4%|▍         | 569/14850 [1:16:44<26:03:51,  6.57s/it]
#   4%|▍         | 570/14850 [1:16:50<26:04:52,  6.58s/it]
#   4%|▍         | 571/14850 [1:16:57<26:00:00,  6.56s/it]
#   4%|▍         | 572/14850 [1:17:03<25:57:52,  6.55s/it]
#   4%|▍         | 573/14850 [1:17:10<25:55:01,  6.54s/it]
#   4%|▍         | 574/14850 [1:17:16<25:53:16,  6.53s/it]
#   4%|▍         | 575/14850 [1:17:25<27:55:32,  7.04s/it]
#   4%|▍         | 576/14850 [1:17:31<27:11:30,  6.86s/it]
#   4%|▍         | 577/14850 [1:17:37<26:41:00,  6.73s/it]
#   4%|▍         | 578/14850 [1:17:44<26:15:25,  6.62s/it]
#   4%|▍         | 579/14850 [1:17:50<26:02:00,  6.57s/it]
#   4%|▍         | 580/14850 [1:17:57<25:57:58,  6.55s/it]
#   4%|▍         | 581/14850 [1:18:03<25:52:59,  6.53s/it]
#   4%|▍         | 582/14850 [1:18:10<25:38:02,  6.47s/it]
#   4%|▍         | 583/14850 [1:18:16<25:35:44,  6.46s/it]
#   4%|▍         | 584/14850 [1:18:22<25:32:05,  6.44s/it]
#   4%|▍         | 585/14850 [1:18:29<25:24:48,  6.41s/it]
#   4%|▍         | 586/14850 [1:18:35<25:30:10,  6.44s/it]
#   4%|▍         | 587/14850 [1:18:42<25:28:21,  6.43s/it]
#   4%|▍         | 588/14850 [1:18:48<25:23:24,  6.41s/it]
#   4%|▍         | 589/14850 [1:18:54<25:23:43,  6.41s/it]
#   4%|▍         | 590/14850 [1:19:01<25:22:24,  6.41s/it]
#   4%|▍         | 591/14850 [1:19:07<25:16:21,  6.38s/it]
#   4%|▍         | 592/14850 [1:19:14<25:11:36,  6.36s/it]
#   4%|▍         | 593/14850 [1:19:20<25:11:48,  6.36s/it]
#   4%|▍         | 594/14850 [1:19:26<25:11:28,  6.36s/it]
#   4%|▍         | 595/14850 [1:19:33<25:08:50,  6.35s/it]
#   4%|▍         | 596/14850 [1:19:39<25:09:50,  6.36s/it]
#   4%|▍         | 597/14850 [1:19:45<25:13:06,  6.37s/it]
#   4%|▍         | 598/14850 [1:19:52<25:14:11,  6.37s/it]
#   4%|▍         | 599/14850 [1:19:58<25:19:44,  6.40s/it]
#   4%|▍         | 600/14850 [1:20:05<25:20:14,  6.40s/it]
#   4%|▍         | 601/14850 [1:20:11<25:19:22,  6.40s/it]
#   4%|▍         | 602/14850 [1:20:17<25:08:09,  6.35s/it]
#   4%|▍         | 603/14850 [1:20:24<25:05:03,  6.34s/it]
#   4%|▍         | 604/14850 [1:20:30<25:08:08,  6.35s/it]
#   4%|▍         | 605/14850 [1:20:36<25:04:11,  6.34s/it]
#   4%|▍         | 606/14850 [1:20:42<24:58:23,  6.31s/it]
#   4%|▍         | 607/14850 [1:20:49<24:56:41,  6.30s/it]
#   4%|▍         | 608/14850 [1:20:55<24:53:32,  6.29s/it]
#   4%|▍         | 609/14850 [1:21:01<24:52:40,  6.29s/it]
#   4%|▍         | 610/14850 [1:21:08<24:49:06,  6.27s/it]
#   4%|▍         | 611/14850 [1:21:14<24:45:17,  6.26s/it]
#   4%|▍         | 612/14850 [1:21:20<24:48:25,  6.27s/it]
#   4%|▍         | 613/14850 [1:21:26<24:47:32,  6.27s/it]
#   4%|▍         | 614/14850 [1:21:33<24:56:28,  6.31s/it]
#   4%|▍         | 615/14850 [1:21:39<24:53:43,  6.30s/it]
#   4%|▍         | 616/14850 [1:21:45<24:51:44,  6.29s/it]
#   4%|▍         | 617/14850 [1:21:52<24:49:04,  6.28s/it]
#   4%|▍         | 618/14850 [1:21:58<24:44:12,  6.26s/it]
#   4%|▍         | 619/14850 [1:22:04<24:46:16,  6.27s/it]
#   4%|▍         | 620/14850 [1:22:10<24:44:52,  6.26s/it]
#   4%|▍         | 621/14850 [1:22:17<24:43:44,  6.26s/it]
#   4%|▍         | 622/14850 [1:22:23<24:46:09,  6.27s/it]
#   4%|▍         | 623/14850 [1:22:29<24:45:59,  6.27s/it]
#   4%|▍         | 624/14850 [1:22:35<24:40:48,  6.25s/it]
#   4%|▍         | 625/14850 [1:22:41<24:35:56,  6.23s/it]
#   4%|▍         | 626/14850 [1:22:48<24:28:50,  6.20s/it]
#   4%|▍         | 627/14850 [1:22:54<24:25:44,  6.18s/it]
#   4%|▍         | 628/14850 [1:23:00<24:30:42,  6.20s/it]
#   4%|▍         | 629/14850 [1:23:06<24:30:19,  6.20s/it]
#   4%|▍         | 630/14850 [1:23:12<24:29:45,  6.20s/it]
#   4%|▍         | 631/14850 [1:23:19<24:31:14,  6.21s/it]
#   4%|▍         | 632/14850 [1:23:25<24:29:18,  6.20s/it]
#   4%|▍         | 633/14850 [1:23:31<24:29:28,  6.20s/it]
#   4%|▍         | 634/14850 [1:23:37<24:24:15,  6.18s/it]
#   4%|▍         | 635/14850 [1:23:43<24:17:29,  6.15s/it]
#   4%|▍         | 636/14850 [1:23:49<24:17:24,  6.15s/it]
#   4%|▍         | 637/14850 [1:23:55<24:09:38,  6.12s/it]
#   4%|▍         | 638/14850 [1:24:01<24:05:07,  6.10s/it]
#   4%|▍         | 639/14850 [1:24:07<23:59:42,  6.08s/it]
#   4%|▍         | 640/14850 [1:24:14<24:01:33,  6.09s/it]
#   4%|▍         | 641/14850 [1:24:20<24:05:41,  6.10s/it]
#   4%|▍         | 642/14850 [1:24:26<24:09:45,  6.12s/it]
#   4%|▍         | 643/14850 [1:24:32<24:14:48,  6.14s/it]
#   4%|▍         | 644/14850 [1:24:38<24:17:25,  6.16s/it]
#   4%|▍         | 645/14850 [1:24:45<24:22:52,  6.18s/it]
#   4%|▍         | 646/14850 [1:24:51<24:24:38,  6.19s/it]
#   4%|▍         | 647/14850 [1:24:57<24:25:21,  6.19s/it]
#   4%|▍         | 648/14850 [1:25:03<24:27:41,  6.20s/it]
#   4%|▍         | 649/14850 [1:25:09<24:25:57,  6.19s/it]
#   4%|▍         | 650/14850 [1:25:15<24:15:18,  6.15s/it]
#   4%|▍         | 651/14850 [1:25:21<24:11:14,  6.13s/it]
#   4%|▍         | 652/14850 [1:25:28<24:09:52,  6.13s/it]
#   4%|▍         | 653/14850 [1:25:34<24:05:29,  6.11s/it]
#   4%|▍         | 654/14850 [1:25:40<24:03:06,  6.10s/it]
#   4%|▍         | 655/14850 [1:25:46<24:09:33,  6.13s/it]
#   4%|▍         | 656/14850 [1:25:52<24:02:27,  6.10s/it]
#   4%|▍         | 657/14850 [1:25:58<23:55:59,  6.07s/it]
#   4%|▍         | 658/14850 [1:26:04<23:53:57,  6.06s/it]
#   4%|▍         | 659/14850 [1:26:10<23:47:32,  6.04s/it]
#   4%|▍         | 660/14850 [1:26:16<23:48:00,  6.04s/it]
#   4%|▍         | 661/14850 [1:26:22<23:45:23,  6.03s/it]
#   4%|▍         | 662/14850 [1:26:28<23:39:01,  6.00s/it]
#   4%|▍         | 663/14850 [1:26:34<23:40:14,  6.01s/it]
#   4%|▍         | 664/14850 [1:26:40<23:40:05,  6.01s/it]
#   4%|▍         | 665/14850 [1:26:46<23:31:32,  5.97s/it]
#   4%|▍         | 666/14850 [1:26:52<23:27:44,  5.95s/it]
#   4%|▍         | 667/14850 [1:26:58<23:25:30,  5.95s/it]
#   4%|▍         | 668/14850 [1:27:04<23:21:30,  5.93s/it]
#   5%|▍         | 669/14850 [1:27:10<23:25:56,  5.95s/it]
#   5%|▍         | 670/14850 [1:27:16<23:26:46,  5.95s/it]
#   5%|▍         | 671/14850 [1:27:22<23:28:55,  5.96s/it]
#   5%|▍         | 672/14850 [1:27:28<24:18:41,  6.17s/it]
#   5%|▍         | 673/14850 [1:27:35<25:18:02,  6.42s/it]
#   5%|▍         | 674/14850 [1:27:41<24:42:43,  6.28s/it]
#   5%|▍         | 675/14850 [1:27:47<24:17:48,  6.17s/it]
#   5%|▍         | 676/14850 [1:27:53<23:58:36,  6.09s/it]
#   5%|▍         | 677/14850 [1:27:59<23:47:32,  6.04s/it]
#   5%|▍         | 678/14850 [1:28:05<23:47:10,  6.04s/it]
#   5%|▍         | 679/14850 [1:28:11<23:46:58,  6.04s/it]
#   5%|▍         | 680/14850 [1:28:17<23:40:13,  6.01s/it]
#   5%|▍         | 681/14850 [1:28:23<23:39:49,  6.01s/it]
#   5%|▍         | 682/14850 [1:28:29<23:36:17,  6.00s/it]
#   5%|▍         | 683/14850 [1:28:35<23:31:41,  5.98s/it]
#   5%|▍         | 684/14850 [1:28:41<23:30:51,  5.98s/it]
#   5%|▍         | 685/14850 [1:28:47<23:39:24,  6.01s/it]
#   5%|▍         | 686/14850 [1:28:53<23:29:49,  5.97s/it]
#   5%|▍         | 687/14850 [1:28:59<23:25:30,  5.95s/it]
#   5%|▍         | 688/14850 [1:29:05<23:27:00,  5.96s/it]
#   5%|▍         | 689/14850 [1:29:11<23:26:37,  5.96s/it]
#   5%|▍         | 690/14850 [1:29:17<23:30:43,  5.98s/it]
#   5%|▍         | 691/14850 [1:29:23<23:30:07,  5.98s/it]
#   5%|▍         | 692/14850 [1:29:29<23:29:40,  5.97s/it]
#   5%|▍         | 693/14850 [1:29:35<23:35:04,  6.00s/it]
#   5%|▍         | 694/14850 [1:29:41<23:33:54,  5.99s/it]
#   5%|▍         | 695/14850 [1:29:46<23:23:43,  5.95s/it]
#   5%|▍         | 696/14850 [1:29:53<23:32:12,  5.99s/it]
#   5%|▍         | 697/14850 [1:29:58<23:23:06,  5.95s/it]
#   5%|▍         | 698/14850 [1:30:04<23:16:25,  5.92s/it]
#   5%|▍         | 699/14850 [1:30:10<23:14:18,  5.91s/it]
#   5%|▍         | 700/14850 [1:30:16<23:13:52,  5.91s/it]
#   5%|▍         | 701/14850 [1:30:22<23:13:08,  5.91s/it]
#   5%|▍         | 702/14850 [1:30:28<23:17:41,  5.93s/it]
#   5%|▍         | 703/14850 [1:30:34<23:15:33,  5.92s/it]
#   5%|▍         | 704/14850 [1:30:40<23:15:49,  5.92s/it]
#   5%|▍         | 705/14850 [1:30:46<23:06:05,  5.88s/it]
#   5%|▍         | 706/14850 [1:30:51<22:51:17,  5.82s/it]
#   5%|▍         | 707/14850 [1:30:57<22:26:45,  5.71s/it]
#   5%|▍         | 708/14850 [1:31:02<22:07:01,  5.63s/it]
#   5%|▍         | 709/14850 [1:31:07<21:40:40,  5.52s/it]
#   5%|▍         | 710/14850 [1:31:12<21:12:35,  5.40s/it]
#   5%|▍         | 711/14850 [1:31:18<20:52:08,  5.31s/it]
#   5%|▍         | 712/14850 [1:31:23<20:30:09,  5.22s/it]
#   5%|▍         | 713/14850 [1:31:28<20:12:38,  5.15s/it]
#   5%|▍         | 714/14850 [1:31:33<20:02:37,  5.10s/it]
#   5%|▍         | 715/14850 [1:31:38<19:57:15,  5.08s/it]
#   5%|▍         | 716/14850 [1:31:43<19:50:34,  5.05s/it]
#   5%|▍         | 717/14850 [1:31:48<19:58:44,  5.09s/it]
#   5%|▍         | 718/14850 [1:31:53<20:00:19,  5.10s/it]
#   5%|▍         | 719/14850 [1:31:58<19:57:10,  5.08s/it]
#   5%|▍         | 720/14850 [1:32:03<20:03:38,  5.11s/it]
#   5%|▍         | 721/14850 [1:32:08<19:58:55,  5.09s/it]
#   5%|▍         | 722/14850 [1:32:13<20:03:18,  5.11s/it]
#   5%|▍         | 723/14850 [1:32:19<20:08:51,  5.13s/it]
#   5%|▍         | 724/14850 [1:32:24<20:06:37,  5.13s/it]
#   5%|▍         | 725/14850 [1:32:29<20:06:01,  5.12s/it]
#   5%|▍         | 726/14850 [1:32:34<20:07:41,  5.13s/it]
#   5%|▍         | 727/14850 [1:32:39<20:07:22,  5.13s/it]
#   5%|▍         | 728/14850 [1:32:44<20:12:49,  5.15s/it]
#   5%|▍         | 729/14850 [1:32:49<20:14:11,  5.16s/it]
#   5%|▍         | 730/14850 [1:32:55<20:12:11,  5.15s/it]
#   5%|▍         | 731/14850 [1:33:00<20:10:03,  5.14s/it]
#   5%|▍         | 732/14850 [1:33:05<20:09:49,  5.14s/it]
#   5%|▍         | 733/14850 [1:33:10<20:10:06,  5.14s/it]
#   5%|▍         | 734/14850 [1:33:15<20:06:24,  5.13s/it]
#   5%|▍         | 735/14850 [1:33:20<20:09:05,  5.14s/it]
#   5%|▍         | 736/14850 [1:33:25<20:06:17,  5.13s/it]
#   5%|▍         | 737/14850 [1:33:30<20:06:08,  5.13s/it]
#   5%|▍         | 738/14850 [1:33:36<20:12:58,  5.16s/it]
#   5%|▍         | 739/14850 [1:33:41<20:18:58,  5.18s/it]
#   5%|▍         | 740/14850 [1:33:46<20:41:57,  5.28s/it]
#   5%|▍         | 741/14850 [1:33:52<20:34:36,  5.25s/it]
#   5%|▍         | 742/14850 [1:33:57<20:30:48,  5.23s/it]
#   5%|▌         | 743/14850 [1:34:02<20:22:54,  5.20s/it]
#   5%|▌         | 744/14850 [1:34:07<20:22:10,  5.20s/it]
#   5%|▌         | 745/14850 [1:34:12<20:16:21,  5.17s/it]
#   5%|▌         | 746/14850 [1:34:17<20:21:22,  5.20s/it]
#   5%|▌         | 747/14850 [1:34:23<20:22:23,  5.20s/it]
#   5%|▌         | 748/14850 [1:34:28<20:16:54,  5.18s/it]
#   5%|▌         | 749/14850 [1:34:33<20:14:26,  5.17s/it]
#   5%|▌         | 750/14850 [1:34:38<20:20:31,  5.19s/it]
#   5%|▌         | 751/14850 [1:34:43<20:22:42,  5.20s/it]
#   5%|▌         | 752/14850 [1:34:49<20:29:42,  5.23s/it]
#   5%|▌         | 753/14850 [1:34:54<20:31:28,  5.24s/it]
#   5%|▌         | 754/14850 [1:34:59<20:44:47,  5.30s/it]
#   5%|▌         | 755/14850 [1:35:05<20:38:50,  5.27s/it]
#   5%|▌         | 756/14850 [1:35:10<20:34:21,  5.25s/it]
#   5%|▌         | 757/14850 [1:35:15<20:31:21,  5.24s/it]
#   5%|▌         | 758/14850 [1:35:20<20:24:24,  5.21s/it]
#   5%|▌         | 759/14850 [1:35:25<20:28:35,  5.23s/it]
#   5%|▌         | 760/14850 [1:35:31<20:25:55,  5.22s/it]
#   5%|▌         | 761/14850 [1:35:36<20:20:31,  5.20s/it]
#   5%|▌         | 762/14850 [1:35:41<20:17:38,  5.19s/it]
#   5%|▌         | 763/14850 [1:35:46<20:14:46,  5.17s/it]
#   5%|▌         | 764/14850 [1:35:51<20:21:15,  5.20s/it]
#   5%|▌         | 765/14850 [1:35:57<20:20:49,  5.20s/it]
#   5%|▌         | 766/14850 [1:36:02<20:53:21,  5.34s/it]
#   5%|▌         | 767/14850 [1:36:08<21:03:39,  5.38s/it]
#   5%|▌         | 768/14850 [1:36:13<20:54:58,  5.35s/it]
#   5%|▌         | 769/14850 [1:36:18<20:50:27,  5.33s/it]
#   5%|▌         | 770/14850 [1:36:23<20:42:07,  5.29s/it]
#   5%|▌         | 771/14850 [1:36:29<20:40:43,  5.29s/it]
#   5%|▌         | 772/14850 [1:36:34<20:45:50,  5.31s/it]
#   5%|▌         | 773/14850 [1:36:39<20:42:20,  5.30s/it]
#   5%|▌         | 774/14850 [1:36:45<20:49:17,  5.33s/it]
#   5%|▌         | 775/14850 [1:36:50<20:44:36,  5.31s/it]
#   5%|▌         | 776/14850 [1:36:55<20:47:57,  5.32s/it]
#   5%|▌         | 777/14850 [1:37:01<20:48:35,  5.32s/it]
#   5%|▌         | 778/14850 [1:37:06<20:53:40,  5.35s/it]
#   5%|▌         | 779/14850 [1:37:12<21:00:14,  5.37s/it]
#   5%|▌         | 780/14850 [1:37:17<20:59:48,  5.37s/it]
#   5%|▌         | 781/14850 [1:37:22<21:00:51,  5.38s/it]
#   5%|▌         | 782/14850 [1:37:28<20:59:42,  5.37s/it]
#   5%|▌         | 783/14850 [1:37:33<21:07:19,  5.41s/it]
#   5%|▌         | 784/14850 [1:37:40<22:39:42,  5.80s/it]
#   5%|▌         | 785/14850 [1:37:45<22:16:15,  5.70s/it]
#   5%|▌         | 786/14850 [1:37:51<22:06:30,  5.66s/it]
#   5%|▌         | 787/14850 [1:37:56<21:55:44,  5.61s/it]
#   5%|▌         | 788/14850 [1:38:02<21:46:07,  5.57s/it]
#   5%|▌         | 789/14850 [1:38:07<21:41:35,  5.55s/it]
#   5%|▌         | 790/14850 [1:38:13<21:36:48,  5.53s/it]
#   5%|▌         | 791/14850 [1:38:18<21:38:21,  5.54s/it]
#   5%|▌         | 792/14850 [1:38:24<21:40:49,  5.55s/it]
#   5%|▌         | 793/14850 [1:38:30<21:41:08,  5.55s/it]
#   5%|▌         | 794/14850 [1:38:35<21:41:45,  5.56s/it]
#   5%|▌         | 795/14850 [1:38:41<21:41:13,  5.55s/it]
#   5%|▌         | 796/14850 [1:38:46<21:48:52,  5.59s/it]
#   5%|▌         | 797/14850 [1:38:52<21:47:34,  5.58s/it]
#   5%|▌         | 798/14850 [1:38:58<21:49:46,  5.59s/it]
#   5%|▌         | 799/14850 [1:39:03<22:05:35,  5.66s/it]
#   5%|▌         | 800/14850 [1:39:09<21:58:58,  5.63s/it]
#   5%|▌         | 801/14850 [1:39:15<22:02:19,  5.65s/it]
#   5%|▌         | 802/14850 [1:39:20<22:03:20,  5.65s/it]
#   5%|▌         | 803/14850 [1:39:26<22:02:07,  5.65s/it]
#   5%|▌         | 804/14850 [1:39:32<22:03:14,  5.65s/it]
#   5%|▌         | 805/14850 [1:39:37<22:09:53,  5.68s/it]
#   5%|▌         | 806/14850 [1:39:43<22:10:53,  5.69s/it]
#   5%|▌         | 807/14850 [1:39:49<22:15:58,  5.71s/it]
#   5%|▌         | 808/14850 [1:39:54<22:14:18,  5.70s/it]
#   5%|▌         | 809/14850 [1:40:00<22:13:42,  5.70s/it]
#   5%|▌         | 810/14850 [1:40:06<22:18:33,  5.72s/it]
#   5%|▌         | 811/14850 [1:40:12<22:20:11,  5.73s/it]
#   5%|▌         | 812/14850 [1:40:17<22:18:50,  5.72s/it]
#   5%|▌         | 813/14850 [1:40:23<22:20:12,  5.73s/it]
#   5%|▌         | 814/14850 [1:40:29<22:21:10,  5.73s/it]
#   5%|▌         | 815/14850 [1:40:35<22:20:34,  5.73s/it]
#   5%|▌         | 816/14850 [1:40:40<22:19:37,  5.73s/it]
#   6%|▌         | 817/14850 [1:40:46<22:25:08,  5.75s/it]
#   6%|▌         | 818/14850 [1:40:52<22:22:23,  5.74s/it]
#   6%|▌         | 819/14850 [1:40:58<22:21:33,  5.74s/it]
#   6%|▌         | 820/14850 [1:41:03<22:20:54,  5.73s/it]
#   6%|▌         | 821/14850 [1:41:09<22:18:37,  5.73s/it]
#   6%|▌         | 822/14850 [1:41:15<22:20:25,  5.73s/it]
#   6%|▌         | 823/14850 [1:41:21<22:22:03,  5.74s/it]
#   6%|▌         | 824/14850 [1:41:26<22:26:51,  5.76s/it]
#   6%|▌         | 825/14850 [1:41:32<22:35:30,  5.80s/it]
#   6%|▌         | 826/14850 [1:41:38<22:38:34,  5.81s/it]
#   6%|▌         | 827/14850 [1:41:44<22:32:33,  5.79s/it]
#   6%|▌         | 828/14850 [1:41:50<22:30:28,  5.78s/it]
#   6%|▌         | 829/14850 [1:41:55<22:29:59,  5.78s/it]
#   6%|▌         | 830/14850 [1:42:01<22:30:36,  5.78s/it]
#   6%|▌         | 831/14850 [1:42:07<22:37:48,  5.81s/it]
#   6%|▌         | 832/14850 [1:42:13<22:47:17,  5.85s/it]
#   6%|▌         | 833/14850 [1:42:19<22:48:27,  5.86s/it]
#   6%|▌         | 834/14850 [1:42:25<22:47:24,  5.85s/it]
#   6%|▌         | 835/14850 [1:42:31<22:50:17,  5.87s/it]
#   6%|▌         | 836/14850 [1:42:36<22:52:10,  5.87s/it]
#   6%|▌         | 837/14850 [1:42:42<22:52:54,  5.88s/it]
#   6%|▌         | 838/14850 [1:42:48<22:47:31,  5.86s/it]
#   6%|▌         | 839/14850 [1:42:54<22:47:28,  5.86s/it]
#   6%|▌         | 840/14850 [1:43:00<22:51:35,  5.87s/it]
#   6%|▌         | 841/14850 [1:43:06<22:51:45,  5.88s/it]
#   6%|▌         | 842/14850 [1:43:12<22:54:18,  5.89s/it]
#   6%|▌         | 843/14850 [1:43:18<22:57:32,  5.90s/it]
#   6%|▌         | 844/14850 [1:43:24<23:00:56,  5.92s/it]
#   6%|▌         | 845/14850 [1:43:30<23:02:30,  5.92s/it]
#   6%|▌         | 846/14850 [1:43:36<23:06:55,  5.94s/it]
#   6%|▌         | 847/14850 [1:43:41<23:07:26,  5.94s/it]
#   6%|▌         | 848/14850 [1:43:47<23:04:04,  5.93s/it]
#   6%|▌         | 849/14850 [1:43:53<23:04:49,  5.93s/it]
#   6%|▌         | 850/14850 [1:43:59<22:55:33,  5.90s/it]
#   6%|▌         | 851/14850 [1:44:05<22:55:23,  5.89s/it]
#   6%|▌         | 852/14850 [1:44:11<22:59:26,  5.91s/it]
#   6%|▌         | 853/14850 [1:44:17<23:05:43,  5.94s/it]
#   6%|▌         | 854/14850 [1:44:23<23:10:46,  5.96s/it]
#   6%|▌         | 855/14850 [1:44:29<23:10:10,  5.96s/it]
#   6%|▌         | 856/14850 [1:44:35<23:08:52,  5.95s/it]
#   6%|▌         | 857/14850 [1:44:41<23:05:42,  5.94s/it]
#   6%|▌         | 858/14850 [1:44:47<23:06:52,  5.95s/it]
#   6%|▌         | 859/14850 [1:44:53<23:08:08,  5.95s/it]
#   6%|▌         | 860/14850 [1:44:59<23:11:04,  5.97s/it]
#   6%|▌         | 861/14850 [1:45:05<23:19:11,  6.00s/it]
#   6%|▌         | 862/14850 [1:45:11<23:26:06,  6.03s/it]
#   6%|▌         | 863/14850 [1:45:17<23:26:49,  6.03s/it]
#   6%|▌         | 864/14850 [1:45:23<23:26:51,  6.04s/it]
#   6%|▌         | 865/14850 [1:45:29<23:29:05,  6.05s/it]
#   6%|▌         | 866/14850 [1:45:35<23:32:14,  6.06s/it]
#   6%|▌         | 867/14850 [1:45:41<23:37:14,  6.08s/it]
#   6%|▌         | 868/14850 [1:45:47<23:44:39,  6.11s/it]
#   6%|▌         | 869/14850 [1:45:54<23:43:25,  6.11s/it]
#   6%|▌         | 870/14850 [1:46:00<23:47:08,  6.13s/it]
#   6%|▌         | 871/14850 [1:46:06<23:44:20,  6.11s/it]
#   6%|▌         | 872/14850 [1:46:12<23:45:25,  6.12s/it]
#   6%|▌         | 873/14850 [1:46:18<23:44:57,  6.12s/it]
#   6%|▌         | 874/14850 [1:46:24<23:44:29,  6.12s/it]
#   6%|▌         | 875/14850 [1:46:30<23:43:35,  6.11s/it]
#   6%|▌         | 876/14850 [1:46:36<23:46:44,  6.13s/it]
#   6%|▌         | 877/14850 [1:46:42<23:43:58,  6.11s/it]
#   6%|▌         | 878/14850 [1:46:49<23:42:48,  6.11s/it]
#   6%|▌         | 879/14850 [1:46:55<23:38:00,  6.09s/it]
#   6%|▌         | 880/14850 [1:47:01<23:27:31,  6.05s/it]
#   6%|▌         | 881/14850 [1:47:07<23:33:31,  6.07s/it]
#   6%|▌         | 882/14850 [1:47:13<23:36:16,  6.08s/it]
#   6%|▌         | 883/14850 [1:47:19<23:40:46,  6.10s/it]
#   6%|▌         | 884/14850 [1:47:25<23:47:55,  6.13s/it]
#   6%|▌         | 885/14850 [1:47:31<23:48:25,  6.14s/it]
#   6%|▌         | 886/14850 [1:47:37<23:51:01,  6.15s/it]
#   6%|▌         | 887/14850 [1:47:44<23:46:24,  6.13s/it]
#   6%|▌         | 888/14850 [1:47:51<24:56:52,  6.43s/it]
#   6%|▌         | 889/14850 [1:47:57<24:37:49,  6.35s/it]
#   6%|▌         | 890/14850 [1:48:03<24:31:12,  6.32s/it]
#   6%|▌         | 891/14850 [1:48:09<24:15:54,  6.26s/it]
#   6%|▌         | 892/14850 [1:48:15<24:09:40,  6.23s/it]
#   6%|▌         | 893/14850 [1:48:22<24:10:47,  6.24s/it]
#   6%|▌         | 894/14850 [1:48:28<24:15:51,  6.26s/it]
#   6%|▌         | 895/14850 [1:48:34<24:20:45,  6.28s/it]
#   6%|▌         | 896/14850 [1:48:41<24:20:08,  6.28s/it]
#   6%|▌         | 897/14850 [1:48:47<24:28:26,  6.31s/it]
#   6%|▌         | 898/14850 [1:48:53<24:30:49,  6.33s/it]
#   6%|▌         | 899/14850 [1:49:00<24:38:15,  6.36s/it]
#   6%|▌         | 900/14850 [1:49:06<24:32:20,  6.33s/it]
#   6%|▌         | 901/14850 [1:49:12<24:31:02,  6.33s/it]
#   6%|▌         | 902/14850 [1:49:19<24:28:55,  6.32s/it]
#   6%|▌         | 903/14850 [1:49:25<24:21:00,  6.29s/it]
#   6%|▌         | 904/14850 [1:49:31<24:23:14,  6.30s/it]
#   6%|▌         | 905/14850 [1:49:37<24:22:17,  6.29s/it]
#   6%|▌         | 906/14850 [1:49:44<24:15:09,  6.26s/it]
#   6%|▌         | 907/14850 [1:49:50<24:15:25,  6.26s/it]
#   6%|▌         | 908/14850 [1:49:56<24:16:23,  6.27s/it]
#   6%|▌         | 909/14850 [1:50:02<24:13:41,  6.26s/it]
#   6%|▌         | 910/14850 [1:50:09<24:15:46,  6.27s/it]
#   6%|▌         | 911/14850 [1:50:15<24:09:36,  6.24s/it]
#   6%|▌         | 912/14850 [1:50:21<24:09:55,  6.24s/it]
#   6%|▌         | 913/14850 [1:50:27<24:14:26,  6.26s/it]
#   6%|▌         | 914/14850 [1:50:34<24:19:34,  6.28s/it]
#   6%|▌         | 915/14850 [1:50:40<24:21:58,  6.29s/it]
#   6%|▌         | 916/14850 [1:50:46<24:22:31,  6.30s/it]
#   6%|▌         | 917/14850 [1:50:53<24:17:23,  6.28s/it]
#   6%|▌         | 918/14850 [1:50:59<24:18:11,  6.28s/it]
#   6%|▌         | 919/14850 [1:51:05<24:25:56,  6.31s/it]
#   6%|▌         | 920/14850 [1:51:12<24:24:59,  6.31s/it]
#   6%|▌         | 921/14850 [1:51:18<24:29:35,  6.33s/it]
#   6%|▌         | 922/14850 [1:51:24<24:29:25,  6.33s/it]
#   6%|▌         | 923/14850 [1:51:31<24:25:47,  6.31s/it]
#   6%|▌         | 924/14850 [1:51:37<24:21:51,  6.30s/it]
#   6%|▌         | 925/14850 [1:51:43<24:24:18,  6.31s/it]
#   6%|▌         | 926/14850 [1:51:50<24:23:51,  6.31s/it]
#   6%|▌         | 927/14850 [1:51:56<24:24:16,  6.31s/it]
#   6%|▌         | 928/14850 [1:52:02<24:28:48,  6.33s/it]
#   6%|▋         | 929/14850 [1:52:09<24:36:59,  6.37s/it]
#   6%|▋         | 930/14850 [1:52:15<24:38:32,  6.37s/it]
#   6%|▋         | 931/14850 [1:52:21<24:41:15,  6.39s/it]
#   6%|▋         | 932/14850 [1:52:28<24:46:10,  6.41s/it]
#   6%|▋         | 933/14850 [1:52:34<24:47:17,  6.41s/it]
#   6%|▋         | 934/14850 [1:52:41<24:50:21,  6.43s/it]
#   6%|▋         | 935/14850 [1:52:47<24:47:17,  6.41s/it]
#   6%|▋         | 936/14850 [1:52:53<24:35:07,  6.36s/it]
#   6%|▋         | 937/14850 [1:53:00<24:42:23,  6.39s/it]
#   6%|▋         | 938/14850 [1:53:06<24:38:15,  6.38s/it]
#   6%|▋         | 939/14850 [1:53:13<24:35:59,  6.37s/it]
#   6%|▋         | 940/14850 [1:53:19<24:36:49,  6.37s/it]
#   6%|▋         | 941/14850 [1:53:25<24:30:27,  6.34s/it]
#   6%|▋         | 942/14850 [1:53:32<24:33:50,  6.36s/it]
#   6%|▋         | 943/14850 [1:53:38<24:40:04,  6.39s/it]
#   6%|▋         | 944/14850 [1:53:44<24:36:37,  6.37s/it]
#   6%|▋         | 945/14850 [1:53:51<24:26:30,  6.33s/it]
#   6%|▋         | 946/14850 [1:53:57<24:25:46,  6.33s/it]
#   6%|▋         | 947/14850 [1:54:03<24:13:11,  6.27s/it]
#   6%|▋         | 948/14850 [1:54:09<24:02:51,  6.23s/it]
#   6%|▋         | 949/14850 [1:54:15<24:05:54,  6.24s/it]
#   6%|▋         | 950/14850 [1:54:22<24:05:30,  6.24s/it]
#   6%|▋         | 951/14850 [1:54:28<23:50:36,  6.18s/it]
#   6%|▋         | 952/14850 [1:54:34<23:52:07,  6.18s/it]
#   6%|▋         | 953/14850 [1:54:40<23:49:36,  6.17s/it]
#   6%|▋         | 954/14850 [1:54:46<23:43:49,  6.15s/it]
#   6%|▋         | 955/14850 [1:54:52<23:29:52,  6.09s/it]
#   6%|▋         | 956/14850 [1:54:58<23:20:09,  6.05s/it]
#   6%|▋         | 957/14850 [1:55:04<23:16:21,  6.03s/it]
#   6%|▋         | 958/14850 [1:55:10<23:11:10,  6.01s/it]
#   6%|▋         | 959/14850 [1:55:16<23:07:53,  5.99s/it]
#   6%|▋         | 960/14850 [1:55:22<23:17:16,  6.04s/it]
#   6%|▋         | 961/14850 [1:55:28<23:21:25,  6.05s/it]
#   6%|▋         | 962/14850 [1:55:34<23:19:28,  6.05s/it]
#   6%|▋         | 963/14850 [1:55:40<23:25:46,  6.07s/it]
#   6%|▋         | 964/14850 [1:55:46<23:25:00,  6.07s/it]
#   6%|▋         | 965/14850 [1:55:52<23:20:09,  6.05s/it]
#   7%|▋         | 966/14850 [1:55:58<23:12:10,  6.02s/it]
#   7%|▋         | 967/14850 [1:56:04<23:10:49,  6.01s/it]
#   7%|▋         | 968/14850 [1:56:10<23:06:26,  5.99s/it]
#   7%|▋         | 969/14850 [1:56:16<23:04:13,  5.98s/it]
#   7%|▋         | 970/14850 [1:56:22<23:08:19,  6.00s/it]
#   7%|▋         | 971/14850 [1:56:28<23:15:21,  6.03s/it]
#   7%|▋         | 972/14850 [1:56:34<23:14:51,  6.03s/it]
#   7%|▋         | 973/14850 [1:56:41<23:38:35,  6.13s/it]
#   7%|▋         | 974/14850 [1:56:47<23:25:04,  6.08s/it]
#   7%|▋         | 975/14850 [1:56:53<23:18:49,  6.05s/it]
#   7%|▋         | 976/14850 [1:56:59<23:17:17,  6.04s/it]
#   7%|▋         | 977/14850 [1:57:05<23:21:48,  6.06s/it]
#   7%|▋         | 978/14850 [1:57:11<23:31:54,  6.11s/it]
#   7%|▋         | 979/14850 [1:57:17<23:30:35,  6.10s/it]
#   7%|▋         | 980/14850 [1:57:23<23:29:25,  6.10s/it]
#   7%|▋         | 981/14850 [1:57:29<23:26:35,  6.09s/it]
#   7%|▋         | 982/14850 [1:57:35<23:29:31,  6.10s/it]
#   7%|▋         | 983/14850 [1:57:42<23:31:52,  6.11s/it]
#   7%|▋         | 984/14850 [1:57:48<23:36:13,  6.13s/it]
#   7%|▋         | 985/14850 [1:57:54<23:54:45,  6.21s/it]
#   7%|▋         | 986/14850 [1:58:01<24:47:46,  6.44s/it]
#   7%|▋         | 987/14850 [1:58:07<24:16:54,  6.31s/it]
#   7%|▋         | 988/14850 [1:58:13<24:05:53,  6.26s/it]
#   7%|▋         | 989/14850 [1:58:19<23:53:33,  6.21s/it]
#   7%|▋         | 990/14850 [1:58:26<23:56:21,  6.22s/it]
#   7%|▋         | 991/14850 [1:58:32<23:44:37,  6.17s/it]
#   7%|▋         | 992/14850 [1:58:38<23:32:19,  6.11s/it]
#   7%|▋         | 993/14850 [1:58:44<23:23:41,  6.08s/it]
#   7%|▋         | 994/14850 [1:58:50<23:21:44,  6.07s/it]
#   7%|▋         | 995/14850 [1:58:56<23:26:25,  6.09s/it]
#   7%|▋         | 996/14850 [1:59:02<23:19:41,  6.06s/it]
#   7%|▋         | 997/14850 [1:59:08<23:17:18,  6.05s/it]
#   7%|▋         | 998/14850 [1:59:14<23:10:15,  6.02s/it]
#   7%|▋         | 999/14850 [1:59:20<23:02:47,  5.99s/it]
#   7%|▋         | 1000/14850 [1:59:26<23:00:20,  5.98s/it]
# Finished Processing!

# %%
print('[INFO]: Video stitching finished')

'''Writing via CV2'''
video_out_path='/content/drive/My Drive/Colab Notebooks/Carla Dataset/Images'

for i in range(len(frames)):
  cv2.imwrite(video_out_path+f"/{i}"+".png", frames[i])
  print("Creating : ",video_out_path,f"/{i}",".png")
# Out:
# [INFO]: Video stitching finished
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /0 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /1 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /2 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /3 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /4 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /5 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /6 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /7 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /8 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /9 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /10 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /11 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /12 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /13 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /14 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /15 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /16 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /17 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /18 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /19 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /20 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /21 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /22 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /23 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /24 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /25 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /26 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /27 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /28 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /29 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /30 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /31 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /32 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /33 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /34 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /35 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /36 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /37 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /38 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /39 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /40 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /41 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /42 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /43 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /44 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /45 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /46 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /47 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /48 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /49 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /50 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /51 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /52 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /53 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /54 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /55 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /56 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /57 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /58 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /59 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /60 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /61 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /62 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /63 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /64 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /65 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /66 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /67 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /68 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /69 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /70 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /71 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /72 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /73 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /74 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /75 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /76 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /77 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /78 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /79 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /80 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /81 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /82 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /83 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /84 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /85 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /86 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /87 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /88 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /89 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /90 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /91 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /92 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /93 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /94 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /95 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /96 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /97 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /98 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /99 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /100 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /101 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /102 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /103 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /104 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /105 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /106 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /107 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /108 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /109 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /110 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /111 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /112 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /113 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /114 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /115 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /116 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /117 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /118 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /119 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /120 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /121 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /122 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /123 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /124 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /125 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /126 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /127 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /128 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /129 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /130 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /131 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /132 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /133 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /134 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /135 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /136 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /137 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /138 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /139 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /140 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /141 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /142 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /143 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /144 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /145 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /146 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /147 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /148 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /149 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /150 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /151 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /152 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /153 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /154 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /155 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /156 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /157 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /158 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /159 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /160 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /161 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /162 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /163 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /164 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /165 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /166 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /167 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /168 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /169 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /170 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /171 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /172 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /173 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /174 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /175 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /176 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /177 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /178 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /179 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /180 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /181 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /182 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /183 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /184 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /185 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /186 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /187 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /188 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /189 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /190 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /191 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /192 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /193 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /194 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /195 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /196 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /197 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /198 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /199 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /200 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /201 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /202 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /203 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /204 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /205 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /206 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /207 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /208 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /209 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /210 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /211 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /212 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /213 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /214 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /215 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /216 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /217 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /218 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /219 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /220 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /221 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /222 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /223 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /224 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /225 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /226 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /227 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /228 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /229 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /230 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /231 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /232 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /233 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /234 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /235 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /236 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /237 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /238 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /239 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /240 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /241 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /242 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /243 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /244 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /245 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /246 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /247 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /248 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /249 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /250 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /251 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /252 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /253 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /254 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /255 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /256 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /257 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /258 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /259 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /260 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /261 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /262 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /263 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /264 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /265 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /266 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /267 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /268 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /269 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /270 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /271 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /272 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /273 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /274 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /275 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /276 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /277 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /278 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /279 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /280 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /281 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /282 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /283 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /284 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /285 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /286 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /287 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /288 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /289 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /290 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /291 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /292 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /293 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /294 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /295 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /296 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /297 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /298 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /299 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /300 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /301 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /302 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /303 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /304 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /305 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /306 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /307 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /308 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /309 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /310 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /311 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /312 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /313 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /314 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /315 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /316 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /317 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /318 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /319 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /320 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /321 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /322 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /323 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /324 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /325 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /326 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /327 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /328 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /329 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /330 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /331 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /332 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /333 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /334 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /335 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /336 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /337 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /338 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /339 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /340 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /341 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /342 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /343 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /344 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /345 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /346 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /347 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /348 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /349 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /350 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /351 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /352 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /353 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /354 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /355 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /356 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /357 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /358 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /359 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /360 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /361 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /362 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /363 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /364 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /365 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /366 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /367 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /368 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /369 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /370 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /371 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /372 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /373 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /374 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /375 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /376 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /377 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /378 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /379 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /380 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /381 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /382 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /383 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /384 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /385 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /386 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /387 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /388 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /389 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /390 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /391 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /392 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /393 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /394 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /395 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /396 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /397 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /398 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /399 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /400 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /401 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /402 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /403 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /404 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /405 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /406 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /407 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /408 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /409 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /410 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /411 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /412 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /413 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /414 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /415 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /416 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /417 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /418 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /419 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /420 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /421 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /422 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /423 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /424 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /425 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /426 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /427 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /428 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /429 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /430 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /431 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /432 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /433 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /434 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /435 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /436 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /437 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /438 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /439 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /440 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /441 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /442 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /443 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /444 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /445 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /446 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /447 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /448 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /449 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /450 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /451 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /452 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /453 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /454 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /455 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /456 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /457 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /458 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /459 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /460 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /461 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /462 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /463 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /464 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /465 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /466 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /467 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /468 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /469 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /470 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /471 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /472 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /473 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /474 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /475 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /476 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /477 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /478 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /479 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /480 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /481 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /482 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /483 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /484 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /485 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /486 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /487 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /488 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /489 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /490 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /491 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /492 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /493 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /494 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /495 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /496 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /497 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /498 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /499 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /500 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /501 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /502 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /503 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /504 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /505 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /506 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /507 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /508 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /509 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /510 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /511 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /512 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /513 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /514 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /515 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /516 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /517 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /518 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /519 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /520 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /521 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /522 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /523 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /524 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /525 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /526 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /527 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /528 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /529 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /530 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /531 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /532 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /533 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /534 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /535 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /536 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /537 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /538 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /539 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /540 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /541 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /542 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /543 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /544 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /545 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /546 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /547 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /548 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /549 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /550 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /551 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /552 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /553 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /554 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /555 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /556 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /557 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /558 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /559 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /560 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /561 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /562 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /563 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /564 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /565 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /566 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /567 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /568 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /569 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /570 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /571 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /572 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /573 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /574 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /575 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /576 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /577 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /578 .png
# ...
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /808 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /809 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /810 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /811 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /812 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /813 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /814 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /815 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /816 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /817 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /818 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /819 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /820 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /821 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /822 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /823 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /824 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /825 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /826 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /827 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /828 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /829 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /830 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /831 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /832 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /833 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /834 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /835 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /836 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /837 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /838 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /839 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /840 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /841 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /842 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /843 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /844 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /845 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /846 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /847 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /848 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /849 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /850 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /851 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /852 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /853 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /854 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /855 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /856 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /857 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /858 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /859 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /860 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /861 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /862 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /863 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /864 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /865 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /866 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /867 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /868 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /869 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /870 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /871 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /872 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /873 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /874 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /875 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /876 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /877 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /878 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /879 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /880 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /881 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /882 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /883 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /884 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /885 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /886 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /887 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /888 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /889 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /890 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /891 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /892 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /893 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /894 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /895 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /896 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /897 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /898 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /899 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /900 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /901 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /902 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /903 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /904 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /905 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /906 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /907 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /908 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /909 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /910 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /911 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /912 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /913 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /914 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /915 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /916 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /917 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /918 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /919 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /920 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /921 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /922 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /923 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /924 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /925 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /926 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /927 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /928 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /929 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /930 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /931 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /932 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /933 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /934 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /935 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /936 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /937 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /938 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /939 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /940 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /941 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /942 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /943 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /944 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /945 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /946 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /947 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /948 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /949 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /950 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /951 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /952 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /953 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /954 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /955 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /956 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /957 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /958 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /959 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /960 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /961 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /962 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /963 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /964 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /965 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /966 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /967 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /968 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /969 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /970 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /971 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /972 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /973 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /974 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /975 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /976 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /977 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /978 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /979 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /980 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /981 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /982 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /983 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /984 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /985 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /986 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /987 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /988 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /989 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /990 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /991 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /992 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /993 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /994 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /995 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /996 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /997 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /998 .png
# Creating :  /content/drive/My Drive/Colab Notebooks/Carla Dataset/Images /999 .png
